# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler

# %%
link = 'https://drive.google.com/file/d/1nMQezyyBWscxQZcEJDifm4cUUq_YsHfZ/view?usp=sharing'
path = "https://drive.google.com/uc?export=download&id="+ link.split("/")[-2]
df_train = pd.read_csv(path)
df_train.head()
# Out:
#                 timestamp_TW                                          uuid  \
# 0  2019-05-23 11:45:00+00:00  MlJ4huAZ055iZHo2BJRhGoCRSYYDeIBv7uGFhaqNYCo=
# 1  2019-06-10 21:15:00+00:00  2pM78+2wOAY8l2evtpJS8Q80s14QI3fjcRZb9QFBVn4=
# 2  2019-06-04 16:15:00+00:00  MJPbRkeq6tFmKeTew2v3sxqobPk6QIJZRgC/dsS1Isc=
# 3  2019-05-15 11:30:00+00:00  qo5D63J1RjT9YPTJsFbKo9GAamD5iF6XMdpGMPaE9g4=
# 4  2019-06-09 10:15:00+00:00  uiyyJRVzplrZoBci1aco8pUxwLFge0tPVNhpYJRoqmc=
#
#                                            ucid  \
# 0  w3a6Wk12CqIrUktZei2Z0W3Rf8xdgEdjIW9QX0MWIf8=
# 1  4MP++M0mzDth2XpfseRILPjwOXOAk+Z2oAquU+nEEYE=
# 2  K1JDDj+chCE/ZH5wzdraQHI2j52Nzy0JBJmeLOgq3vc=
# 3  Y+91ladMQTxor3mEVlnYFcmpwmJFyT1HMG+DNySbVZ4=
# 4  bL9LCeyWY9s37YHGGaajw9y6AvwkTvCxHwEL9prznXk=
#
#                                            upid  problem_number  \
# 0  Q5jLvHRQpMUYKZZ6GbotWYCMvkMPq1+yCtpCzTrZW1A=               2
# 1  G4w1QQMbjRT/VptQIZkGYZhO/nkDJiC5ELv+TYfyPHM=               7
# 2  9c2hrY//vjfzCDODz8sOIragypxFG49b/t9S91Krlkg=              14
# 3  ZoE4lwjhMFd9OaWebsWlnK9s1AHSSpuSx8gO7gcplTA=              47
# 4  v4fB2VzIvLxBidz/bupuh6clyMuvR2b8BgSz6PA5UI4=               1
#
#    exercise_problem_repeat_session  is_correct  total_sec_taken  \
# 0                                1        True               29
# 1                                1       False               69
# 2                                1       False               49
# 3                                2        True                9
# 4                                1       False               56
#
#    total_attempt_cnt  used_hint_cnt   points  badges_cnt  is_self_coach  \
# 0                  1              0    28444           7          False
# 1                 19              3   305999          99          False
# 2                  4              2    71162          28          False
# 3                  1              0    47540          13          False
# 4                  2              2  1100969         105          False
#
#    has_student_cnt  belongs_to_class_cnt difficulty learning_stage  cheating
# 0                0                     1       easy     elementary         1
# 1                0                     1       hard     elementary         0
# 2                0                     0       easy         junior         1
# 3                0                     0     normal         junior         0
# 4                0                     1       easy     elementary         0

# %%
print(df_train['cheating'].value_counts())
# Out:
# cheating
# 0    5236
# 1    4793
# Name: count, dtype: int64

# %%
link1 = 'https://drive.google.com/file/d/1muldXGM0lM0hXQHXDyTQNIqjBQPUbSmZ/view?usp=sharing'
path1 = "https://drive.google.com/uc?export=download&id="+ link1.split("/")[-2]
df_test = pd.read_csv(path1)
df_test.head()
# Out:
#                 timestamp_TW                                          uuid  \
# 0  2019-06-04 16:45:00+00:00  +Oo+ob0YK/yFBooA6Nf3OW36y7Gr/b6/ba4a6UME/0A=
# 1  2019-05-21 21:15:00+00:00  mswQBRjmFKewBZnx/zGLKNkgr6Qf5pxv2uge48uqKcU=
# 2  2019-05-31 16:00:00+00:00  QOnOU/aC/jpVXnQanzAbc+E647O5X+nzhGt5VTIcF+c=
# 3  2019-06-11 20:30:00+00:00  J1IpAXiX5/aDRXwY49vUC1iB8B2LBN8Z5Ly4BF+p8ws=
# 4  2019-06-05 22:45:00+00:00  gzAyQpaHDzkY9/IFCbW3JvIolRnpInuj0pJWnSbLwwg=
#
#                                            ucid  \
# 0  3yFVYhjNhMP7tnJJxuCoKfPObXOoeoA5CWP2jeb05pw=
# 1  jImuGvSym6odgRoYw7vgkq4HUbmJ1tDW9fq6bo/yN5s=
# 2  tBr8loWJrEOlzcZDaQL0Q2qMEMUVGJJiWePsXb+7O9U=
# 3  PqQyQvOjvvozBCtlR/0pL8uxhe0K63IPiKYCi1tDG1o=
# 4  yHgHyIJ05U7s8Ak1XnUHY08MP++zF14JXnyie5AL5s0=
#
#                                            upid  problem_number  \
# 0  ER8ng3Tve+gXz0rzE4j8vVQVxJQG9pViFuppcTPCiXs=              16
# 1  EhczsL8/+nNXjaQ9riKSnb9DqC+HCnsSl3iDYW99ixQ=               5
# 2  QGivcV7dEtlX9vq1WVsW9i5jjJ7IeUgUbV8xot9rfbU=               2
# 3  F80i4frwlUPyjWehI764RoG6nzkEcPmKb6+1HcEJXHE=               5
# 4  k7bHRN1JubCEXM7IVXwABfq01n/9pN30eOrL1A8z2yc=              16
#
#    exercise_problem_repeat_session  is_correct  total_sec_taken  \
# 0                                1       False                9
# 1                                1        True               13
# 2                                1        True               39
# 3                                1       False               11
# 4                                2       False               21
#
#    total_attempt_cnt  used_hint_cnt  points  badges_cnt  is_self_coach  \
# 0                  4              1   80647          29          False
# 1                  1              0  239838          35          False
# 2                  1              0  143843          15          False
# 3                  3              0   34960           1          False
# 4                  7              4  219276          70          False
#
#    has_student_cnt  belongs_to_class_cnt difficulty learning_stage  cheating
# 0                0                     1     normal         junior         0
# 1                0                     1       easy     elementary         1
# 2                0                     2     normal     elementary         0
# 3                0                     1       easy     elementary         0
# 4                0                     1       hard     elementary         0

# %%
# One-hot encoding for Difficulty and Learning_stage columns
difficulty_encoded = pd.get_dummies(df_train['difficulty'], prefix='difficulty')
df_train = pd.concat([df_train, difficulty_encoded], axis=1)
df_train = df_train.drop('difficulty', axis=1)
df_train['learning_stage'] = df_train['learning_stage'].replace({'elementary': 1, 'junior': 2, 'senior': 3})

difficulty_encoded1 = pd.get_dummies(df_test['difficulty'], prefix='difficulty')
df_test = pd.concat([df_test, difficulty_encoded1], axis=1)
df_test = df_test.drop('difficulty', axis=1)
df_test['learning_stage'] = df_test['learning_stage'].replace({'elementary': 1, 'junior': 2, 'senior': 3})
# Out:
# /tmp/ipython-input-6-99201639.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_train['learning_stage'] = df_train['learning_stage'].replace({'elementary': 1, 'junior': 2, 'senior': 3})
# /tmp/ipython-input-6-99201639.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_test['learning_stage'] = df_test['learning_stage'].replace({'elementary': 1, 'junior': 2, 'senior': 3})

# %%
df_train['timestamp_TW'] = pd.to_datetime(df_train['timestamp_TW'])
df_train['hour'] = df_train['timestamp_TW'].dt.hour
df_train['minute'] = df_train['timestamp_TW'].dt.minute
df_train['weekday'] = df_train['timestamp_TW'].dt.weekday
df_train['day'] = df_train['timestamp_TW'].dt.day
df_train['month'] = df_train['timestamp_TW'].dt.month

df_test['timestamp_TW'] = pd.to_datetime(df_test['timestamp_TW'])
df_test['hour'] = df_test['timestamp_TW'].dt.hour
df_test['minute'] = df_test['timestamp_TW'].dt.minute
df_test['weekday'] = df_test['timestamp_TW'].dt.weekday
df_test['day'] = df_test['timestamp_TW'].dt.day
df_test['month'] = df_test['timestamp_TW'].dt.month

# %%
df_train =df_train.drop(columns = 'timestamp_TW')
df_test =df_test.drop(columns = 'timestamp_TW')

# %%
df_train = df_train.drop(columns = ['uuid', 'ucid', 'upid'])
df_test = df_test.drop(columns = ['uuid', 'ucid', 'upid'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10029 entries, 0 to 10028
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   problem_number                   10029 non-null  int64
#  1   exercise_problem_repeat_session  10029 non-null  int64
#  2   is_correct                       10029 non-null  bool
#  3   total_sec_taken                  10029 non-null  int64
#  4   total_attempt_cnt                10029 non-null  int64
#  5   used_hint_cnt                    10029 non-null  int64
#  6   points                           10029 non-null  int64
#  7   badges_cnt                       10029 non-null  int64
#  8   is_self_coach                    10029 non-null  bool
#  9   has_student_cnt                  10029 non-null  int64
#  10  belongs_to_class_cnt             10029 non-null  int64
#  11  learning_stage                   10029 non-null  int64
#  12  cheating                         10029 non-null  int64
#  13  difficulty_easy                  10029 non-null  bool
#  14  difficulty_hard                  10029 non-null  bool
#  15  difficulty_normal                10029 non-null  bool
#  16  hour                             10029 non-null  int32
#  17  minute                           10029 non-null  int32
#  18  weekday                          10029 non-null  int32
#  19  day                              10029 non-null  int32
#  20  month                            10029 non-null  int32
# dtypes: bool(5), int32(5), int64(11)
# memory usage: 1.1 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2508 entries, 0 to 2507
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   problem_number                   2508 non-null   int64
#  1   exercise_problem_repeat_session  2508 non-null   int64
#  2   is_correct                       2508 non-null   bool
#  3   total_sec_taken                  2508 non-null   int64
#  4   total_attempt_cnt                2508 non-null   int64
#  5   used_hint_cnt                    2508 non-null   int64
#  6   points                           2508 non-null   int64
#  7   badges_cnt                       2508 non-null   int64
#  8   is_self_coach                    2508 non-null   bool
#  9   has_student_cnt                  2508 non-null   int64
#  10  belongs_to_class_cnt             2508 non-null   int64
#  11  learning_stage                   2508 non-null   int64
#  12  cheating                         2508 non-null   int64
#  13  difficulty_easy                  2508 non-null   bool
#  14  difficulty_hard                  2508 non-null   bool
#  15  difficulty_normal                2508 non-null   bool
#  16  hour                             2508 non-null   int32
#  17  minute                           2508 non-null   int32
#  18  weekday                          2508 non-null   int32
#  19  day                              2508 non-null   int32
#  20  month                            2508 non-null   int32
# dtypes: bool(5), int32(5), int64(11)
# memory usage: 276.9 KB

# %%
X_train = df_train.drop(columns = "cheating")
y_train = df_train["cheating"]
print(X_train.shape)

X_test = df_test.drop(columns="cheating")
y_test = df_test["cheating"]
print(X_test.shape)
# Out:
# (10029, 20)
# (2508, 20)

# %%
# !pip install pytorch_tabnet
# Out:
# Collecting pytorch_tabnet
#   Downloading pytorch_tabnet-4.1.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (2.0.2)
# Requirement already satisfied: scikit_learn>0.21 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (1.6.1)
# Requirement already satisfied: scipy>1.4 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (1.15.3)
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (2.6.0+cu124)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (4.67.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit_learn>0.21->pytorch_tabnet) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit_learn>0.21->pytorch_tabnet) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.3->pytorch_tabnet) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3->pytorch_tabnet) (3.0.2)
# Downloading pytorch_tabnet-4.1.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 2.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 61.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 27.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 38.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, pytorch_tabnet
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pytorch_tabnet-4.1.0

# %%
from pytorch_tabnet.tab_model import TabNetClassifier
import torch

cat_idxs = []
cat_dims = []
cat_emb_dim = []

# Trọng số xử lý mất cân bằng
class_weights = {0: 1, 1: 1.5}


# Khởi tạo mô hình TabNetClassifier với đầy đủ tham số
clf = TabNetClassifier(
    n_d=16, n_a=16,  # Kích thước decision layer & attention
    n_steps=7, gamma=1.5,  # Số bước và độ tái sử dụng feature
    n_independent=2, n_shared=2,  # Kiểm soát số lớp chung & riêng
    cat_idxs=cat_idxs, cat_emb_dim=cat_emb_dim,  # Embedding categorical
    optimizer_fn=torch.optim.Adam,  # Sử dụng Adam Optimizer
    optimizer_params=dict(lr=0.02),  # Learning rate = 0.02
    scheduler_fn=torch.optim.lr_scheduler.StepLR,
    scheduler_params={"step_size":10, "gamma":0.9},
    mask_type="sparsemax",  # Sử dụng sparsemax cho feature selection
    lambda_sparse=1e-3,  # Điều chỉnh sparsity để chọn lọc feature
    momentum=0.02,  # BatchNorm momentum
    clip_value=2.0,  # Clipping gradient
    verbose=1,  # Hiển thị log
    device_name='auto'
)
# Convert boolean columns to integers (0 or 1)
for col in X_train.select_dtypes(include=['bool']).columns:
    X_train[col] = X_train[col].astype(int)
    X_test[col] = X_test[col].astype(int)

X_train_np = X_train.values  # Chuyển thành NumPy array
X_test_np = X_test.values
y_train_np = y_train.values
y_test_np = y_test.values

# Huấn luyện mô hình
clf.fit(
    X_train_np, y_train_np,
    eval_set=[(X_train_np, y_train_np), (X_test_np, y_test_np)],
    eval_name=['train', 'test'],
    eval_metric=['auc', 'balanced_accuracy', 'logloss'],
    max_epochs=100, patience=60,
    batch_size=512, virtual_batch_size=128,
    num_workers=0,
    weights=class_weights,  # Trọng số cho lớp mất cân bằng
    drop_last=False
)
# Out:
# /usr/local/lib/python3.11/dist-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 1.01357 | train_auc: 0.50417 | train_balanced_accuracy: 0.49633 | train_logloss: 2.09149 | test_auc: 0.48715 | test_balanced_accuracy: 0.49037 | test_logloss: 2.43917 |  0:00:03s
# epoch 1  | loss: 0.75305 | train_auc: 0.51238 | train_balanced_accuracy: 0.50813 | train_logloss: 0.83619 | test_auc: 0.55606 | test_balanced_accuracy: 0.53199 | test_logloss: 0.90732 |  0:00:06s
# epoch 2  | loss: 0.71592 | train_auc: 0.51234 | train_balanced_accuracy: 0.50229 | train_logloss: 0.80259 | test_auc: 0.57688 | test_balanced_accuracy: 0.5121  | test_logloss: 0.84477 |  0:00:08s
# epoch 3  | loss: 0.69068 | train_auc: 0.52466 | train_balanced_accuracy: 0.5072  | train_logloss: 0.7197  | test_auc: 0.64383 | test_balanced_accuracy: 0.53084 | test_logloss: 0.73353 |  0:00:11s
# epoch 4  | loss: 0.68178 | train_auc: 0.52391 | train_balanced_accuracy: 0.5007  | train_logloss: 0.73298 | test_auc: 0.58589 | test_balanced_accuracy: 0.50519 | test_logloss: 0.77477 |  0:00:13s
# epoch 5  | loss: 0.68137 | train_auc: 0.55164 | train_balanced_accuracy: 0.50101 | train_logloss: 0.72227 | test_auc: 0.70491 | test_balanced_accuracy: 0.50222 | test_logloss: 0.74389 |  0:00:15s
# epoch 6  | loss: 0.67949 | train_auc: 0.54851 | train_balanced_accuracy: 0.50162 | train_logloss: 0.72091 | test_auc: 0.69042 | test_balanced_accuracy: 0.50652 | test_logloss: 0.74823 |  0:00:18s
# epoch 7  | loss: 0.67962 | train_auc: 0.55639 | train_balanced_accuracy: 0.526   | train_logloss: 0.69932 | test_auc: 0.74941 | test_balanced_accuracy: 0.59984 | test_logloss: 0.69542 |  0:00:21s
# epoch 8  | loss: 0.68075 | train_auc: 0.55018 | train_balanced_accuracy: 0.50751 | train_logloss: 0.70583 | test_auc: 0.73203 | test_balanced_accuracy: 0.53537 | test_logloss: 0.71133 |  0:00:23s
# epoch 9  | loss: 0.67985 | train_auc: 0.55159 | train_balanced_accuracy: 0.51573 | train_logloss: 0.70046 | test_auc: 0.73186 | test_balanced_accuracy: 0.56463 | test_logloss: 0.70103 |  0:00:25s
# epoch 10 | loss: 0.67968 | train_auc: 0.55416 | train_balanced_accuracy: 0.51278 | train_logloss: 0.71579 | test_auc: 0.73587 | test_balanced_accuracy: 0.54826 | test_logloss: 0.722   |  0:00:27s
# epoch 11 | loss: 0.67976 | train_auc: 0.54919 | train_balanced_accuracy: 0.51392 | train_logloss: 0.71093 | test_auc: 0.68174 | test_balanced_accuracy: 0.53746 | test_logloss: 0.7217  |  0:00:31s
# epoch 12 | loss: 0.68005 | train_auc: 0.54649 | train_balanced_accuracy: 0.52294 | train_logloss: 0.69977 | test_auc: 0.67899 | test_balanced_accuracy: 0.59095 | test_logloss: 0.6923  |  0:00:33s
# epoch 13 | loss: 0.67823 | train_auc: 0.54913 | train_balanced_accuracy: 0.52081 | train_logloss: 0.70473 | test_auc: 0.71453 | test_balanced_accuracy: 0.57628 | test_logloss: 0.70979 |  0:00:35s
# epoch 14 | loss: 0.67672 | train_auc: 0.55593 | train_balanced_accuracy: 0.51069 | train_logloss: 0.70973 | test_auc: 0.71406 | test_balanced_accuracy: 0.54573 | test_logloss: 0.72442 |  0:00:37s
# epoch 15 | loss: 0.6739  | train_auc: 0.558   | train_balanced_accuracy: 0.51158 | train_logloss: 0.71406 | test_auc: 0.71718 | test_balanced_accuracy: 0.55738 | test_logloss: 0.72804 |  0:00:40s
# epoch 16 | loss: 0.67621 | train_auc: 0.55822 | train_balanced_accuracy: 0.52207 | train_logloss: 0.70261 | test_auc: 0.72583 | test_balanced_accuracy: 0.59028 | test_logloss: 0.70556 |  0:00:42s
# epoch 17 | loss: 0.67569 | train_auc: 0.55606 | train_balanced_accuracy: 0.50853 | train_logloss: 0.71445 | test_auc: 0.74925 | test_balanced_accuracy: 0.54326 | test_logloss: 0.72169 |  0:00:45s
# epoch 18 | loss: 0.67877 | train_auc: 0.55526 | train_balanced_accuracy: 0.51398 | train_logloss: 0.70256 | test_auc: 0.68541 | test_balanced_accuracy: 0.52796 | test_logloss: 0.71526 |  0:00:47s
# epoch 19 | loss: 0.67686 | train_auc: 0.5595  | train_balanced_accuracy: 0.52297 | train_logloss: 0.70808 | test_auc: 0.71507 | test_balanced_accuracy: 0.56758 | test_logloss: 0.71515 |  0:00:49s
# epoch 20 | loss: 0.67339 | train_auc: 0.56251 | train_balanced_accuracy: 0.52991 | train_logloss: 0.70364 | test_auc: 0.72739 | test_balanced_accuracy: 0.5962  | test_logloss: 0.70227 |  0:00:51s
# epoch 21 | loss: 0.67522 | train_auc: 0.56266 | train_balanced_accuracy: 0.52915 | train_logloss: 0.71275 | test_auc: 0.73419 | test_balanced_accuracy: 0.60003 | test_logloss: 0.71838 |  0:00:53s
# epoch 22 | loss: 0.67564 | train_auc: 0.56054 | train_balanced_accuracy: 0.52373 | train_logloss: 0.70259 | test_auc: 0.72715 | test_balanced_accuracy: 0.56963 | test_logloss: 0.70414 |  0:00:56s
# epoch 23 | loss: 0.67542 | train_auc: 0.56311 | train_balanced_accuracy: 0.52083 | train_logloss: 0.70029 | test_auc: 0.75111 | test_balanced_accuracy: 0.57926 | test_logloss: 0.69351 |  0:00:59s
# epoch 24 | loss: 0.67637 | train_auc: 0.56303 | train_balanced_accuracy: 0.51651 | train_logloss: 0.71019 | test_auc: 0.7515  | test_balanced_accuracy: 0.55991 | test_logloss: 0.71328 |  0:01:01s
# epoch 25 | loss: 0.67443 | train_auc: 0.56062 | train_balanced_accuracy: 0.51105 | train_logloss: 0.70621 | test_auc: 0.73483 | test_balanced_accuracy: 0.53515 | test_logloss: 0.71716 |  0:01:04s
# epoch 26 | loss: 0.67472 | train_auc: 0.56236 | train_balanced_accuracy: 0.52047 | train_logloss: 0.71139 | test_auc: 0.7352  | test_balanced_accuracy: 0.56317 | test_logloss: 0.71895 |  0:01:06s
# epoch 27 | loss: 0.67522 | train_auc: 0.56506 | train_balanced_accuracy: 0.53371 | train_logloss: 0.69713 | test_auc: 0.75691 | test_balanced_accuracy: 0.62917 | test_logloss: 0.68432 |  0:01:09s
# epoch 28 | loss: 0.67902 | train_auc: 0.5608  | train_balanced_accuracy: 0.53788 | train_logloss: 0.69129 | test_auc: 0.72975 | test_balanced_accuracy: 0.65631 | test_logloss: 0.67084 |  0:01:11s
# epoch 29 | loss: 0.67743 | train_auc: 0.56191 | train_balanced_accuracy: 0.50921 | train_logloss: 0.72324 | test_auc: 0.74612 | test_balanced_accuracy: 0.52692 | test_logloss: 0.74041 |  0:01:14s
# epoch 30 | loss: 0.68192 | train_auc: 0.5629  | train_balanced_accuracy: 0.51269 | train_logloss: 0.71743 | test_auc: 0.72717 | test_balanced_accuracy: 0.5361  | test_logloss: 0.73346 |  0:01:16s
# epoch 31 | loss: 0.67427 | train_auc: 0.56735 | train_balanced_accuracy: 0.52113 | train_logloss: 0.70374 | test_auc: 0.74605 | test_balanced_accuracy: 0.55757 | test_logloss: 0.70695 |  0:01:19s
# epoch 32 | loss: 0.67605 | train_auc: 0.56684 | train_balanced_accuracy: 0.53591 | train_logloss: 0.70038 | test_auc: 0.75548 | test_balanced_accuracy: 0.60858 | test_logloss: 0.69365 |  0:01:22s
# epoch 33 | loss: 0.6743  | train_auc: 0.56904 | train_balanced_accuracy: 0.5193  | train_logloss: 0.70579 | test_auc: 0.7565  | test_balanced_accuracy: 0.54022 | test_logloss: 0.70927 |  0:01:24s
# epoch 34 | loss: 0.67498 | train_auc: 0.56875 | train_balanced_accuracy: 0.53293 | train_logloss: 0.70009 | test_auc: 0.76532 | test_balanced_accuracy: 0.5905  | test_logloss: 0.69316 |  0:01:26s
# epoch 35 | loss: 0.67439 | train_auc: 0.56927 | train_balanced_accuracy: 0.53676 | train_logloss: 0.7015  | test_auc: 0.77159 | test_balanced_accuracy: 0.64462 | test_logloss: 0.68352 |  0:01:29s
# epoch 36 | loss: 0.67489 | train_auc: 0.56558 | train_balanced_accuracy: 0.52124 | train_logloss: 0.70668 | test_auc: 0.75545 | test_balanced_accuracy: 0.55979 | test_logloss: 0.70914 |  0:01:33s
# epoch 37 | loss: 0.67586 | train_auc: 0.56195 | train_balanced_accuracy: 0.53976 | train_logloss: 0.70851 | test_auc: 0.76533 | test_balanced_accuracy: 0.6444  | test_logloss: 0.69571 |  0:01:35s
# epoch 38 | loss: 0.67335 | train_auc: 0.55806 | train_balanced_accuracy: 0.50678 | train_logloss: 0.71382 | test_auc: 0.75672 | test_balanced_accuracy: 0.52004 | test_logloss: 0.72475 |  0:01:37s
# epoch 39 | loss: 0.6787  | train_auc: 0.55777 | train_balanced_accuracy: 0.53896 | train_logloss: 0.70178 | test_auc: 0.74015 | test_balanced_accuracy: 0.63987 | test_logloss: 0.68327 |  0:01:39s
# epoch 40 | loss: 0.67392 | train_auc: 0.55755 | train_balanced_accuracy: 0.50746 | train_logloss: 0.70947 | test_auc: 0.77227 | test_balanced_accuracy: 0.5368  | test_logloss: 0.71343 |  0:01:42s
# epoch 41 | loss: 0.67744 | train_auc: 0.55991 | train_balanced_accuracy: 0.52191 | train_logloss: 0.70967 | test_auc: 0.74382 | test_balanced_accuracy: 0.58021 | test_logloss: 0.70925 |  0:01:44s
# epoch 42 | loss: 0.67897 | train_auc: 0.56053 | train_balanced_accuracy: 0.53045 | train_logloss: 0.70004 | test_auc: 0.75916 | test_balanced_accuracy: 0.59712 | test_logloss: 0.69795 |  0:01:46s
# epoch 43 | loss: 0.67738 | train_auc: 0.56526 | train_balanced_accuracy: 0.51562 | train_logloss: 0.70821 | test_auc: 0.81449 | test_balanced_accuracy: 0.57461 | test_logloss: 0.69993 |  0:01:49s
# epoch 44 | loss: 0.67365 | train_auc: 0.5568  | train_balanced_accuracy: 0.50089 | train_logloss: 0.72037 | test_auc: 0.7423  | test_balanced_accuracy: 0.49962 | test_logloss: 0.73871 |  0:01:51s
# epoch 45 | loss: 0.67515 | train_auc: 0.57075 | train_balanced_accuracy: 0.50433 | train_logloss: 0.72774 | test_auc: 0.81572 | test_balanced_accuracy: 0.51457 | test_logloss: 0.73021 |  0:01:53s
# epoch 46 | loss: 0.67188 | train_auc: 0.57338 | train_balanced_accuracy: 0.53566 | train_logloss: 0.70662 | test_auc: 0.79481 | test_balanced_accuracy: 0.63132 | test_logloss: 0.69081 |  0:01:55s
# epoch 47 | loss: 0.67021 | train_auc: 0.56848 | train_balanced_accuracy: 0.5256  | train_logloss: 0.70917 | test_auc: 0.81843 | test_balanced_accuracy: 0.59626 | test_logloss: 0.69741 |  0:01:58s
# epoch 48 | loss: 0.67671 | train_auc: 0.56476 | train_balanced_accuracy: 0.51852 | train_logloss: 0.69622 | test_auc: 0.78207 | test_balanced_accuracy: 0.55758 | test_logloss: 0.68489 |  0:02:00s
# epoch 49 | loss: 0.67178 | train_auc: 0.57754 | train_balanced_accuracy: 0.53405 | train_logloss: 0.70019 | test_auc: 0.8503  | test_balanced_accuracy: 0.61093 | test_logloss: 0.68185 |  0:02:02s
# epoch 50 | loss: 0.67189 | train_auc: 0.5774  | train_balanced_accuracy: 0.51811 | train_logloss: 0.73503 | test_auc: 0.83963 | test_balanced_accuracy: 0.5564  | test_logloss: 0.6972  |  0:02:04s
# epoch 51 | loss: 0.6691  | train_auc: 0.5835  | train_balanced_accuracy: 0.52904 | train_logloss: 0.71018 | test_auc: 0.89525 | test_balanced_accuracy: 0.59557 | test_logloss: 0.67278 |  0:02:06s
# epoch 52 | loss: 0.6737  | train_auc: 0.58214 | train_balanced_accuracy: 0.52044 | train_logloss: 0.70184 | test_auc: 0.87723 | test_balanced_accuracy: 0.55893 | test_logloss: 0.69145 |  0:02:08s
# epoch 53 | loss: 0.67219 | train_auc: 0.5689  | train_balanced_accuracy: 0.52813 | train_logloss: 0.69834 | test_auc: 0.80794 | test_balanced_accuracy: 0.58651 | test_logloss: 0.68917 |  0:02:11s
# epoch 54 | loss: 0.67266 | train_auc: 0.57829 | train_balanced_accuracy: 0.51899 | train_logloss: 0.70699 | test_auc: 0.86461 | test_balanced_accuracy: 0.55731 | test_logloss: 0.69907 |  0:02:13s
# epoch 55 | loss: 0.67277 | train_auc: 0.56097 | train_balanced_accuracy: 0.52956 | train_logloss: 0.69484 | test_auc: 0.78496 | test_balanced_accuracy: 0.61891 | test_logloss: 0.68582 |  0:02:15s
# epoch 56 | loss: 0.67753 | train_auc: 0.5796  | train_balanced_accuracy: 0.51942 | train_logloss: 0.70237 | test_auc: 0.90306 | test_balanced_accuracy: 0.56225 | test_logloss: 0.68257 |  0:02:17s
# epoch 57 | loss: 0.67012 | train_auc: 0.57952 | train_balanced_accuracy: 0.53068 | train_logloss: 0.7026  | test_auc: 0.8837  | test_balanced_accuracy: 0.6208  | test_logloss: 0.66995 |  0:02:19s
# epoch 58 | loss: 0.67832 | train_auc: 0.55582 | train_balanced_accuracy: 0.51712 | train_logloss: 0.70371 | test_auc: 0.81259 | test_balanced_accuracy: 0.56713 | test_logloss: 0.70088 |  0:02:22s
# epoch 59 | loss: 0.67347 | train_auc: 0.57997 | train_balanced_accuracy: 0.51989 | train_logloss: 0.70291 | test_auc: 0.89726 | test_balanced_accuracy: 0.55181 | test_logloss: 0.69278 |  0:02:24s
# epoch 60 | loss: 0.67583 | train_auc: 0.58006 | train_balanced_accuracy: 0.51164 | train_logloss: 0.69974 | test_auc: 0.91301 | test_balanced_accuracy: 0.52448 | test_logloss: 0.68698 |  0:02:27s
# epoch 61 | loss: 0.67113 | train_auc: 0.58815 | train_balanced_accuracy: 0.52495 | train_logloss: 0.6991  | test_auc: 0.94904 | test_balanced_accuracy: 0.59094 | test_logloss: 0.66673 |  0:02:29s
# epoch 62 | loss: 0.67161 | train_auc: 0.58336 | train_balanced_accuracy: 0.52826 | train_logloss: 0.69846 | test_auc: 0.93117 | test_balanced_accuracy: 0.5925  | test_logloss: 0.66881 |  0:02:31s
# epoch 63 | loss: 0.66815 | train_auc: 0.58616 | train_balanced_accuracy: 0.52632 | train_logloss: 0.69646 | test_auc: 0.94563 | test_balanced_accuracy: 0.59018 | test_logloss: 0.66307 |  0:02:33s
# epoch 64 | loss: 0.66858 | train_auc: 0.58537 | train_balanced_accuracy: 0.52784 | train_logloss: 0.69505 | test_auc: 0.93474 | test_balanced_accuracy: 0.62074 | test_logloss: 0.66056 |  0:02:36s
# epoch 65 | loss: 0.66929 | train_auc: 0.58477 | train_balanced_accuracy: 0.52465 | train_logloss: 0.69911 | test_auc: 0.9386  | test_balanced_accuracy: 0.58958 | test_logloss: 0.66254 |  0:02:38s
# epoch 66 | loss: 0.67185 | train_auc: 0.58436 | train_balanced_accuracy: 0.52783 | train_logloss: 0.69294 | test_auc: 0.9347  | test_balanced_accuracy: 0.62077 | test_logloss: 0.65399 |  0:02:40s
# epoch 67 | loss: 0.66952 | train_auc: 0.58586 | train_balanced_accuracy: 0.53214 | train_logloss: 0.69391 | test_auc: 0.94915 | test_balanced_accuracy: 0.64582 | test_logloss: 0.64989 |  0:02:42s
# epoch 68 | loss: 0.67316 | train_auc: 0.56411 | train_balanced_accuracy: 0.53864 | train_logloss: 0.69273 | test_auc: 0.80405 | test_balanced_accuracy: 0.66346 | test_logloss: 0.67774 |  0:02:44s
# epoch 69 | loss: 0.67556 | train_auc: 0.56994 | train_balanced_accuracy: 0.53124 | train_logloss: 0.6936  | test_auc: 0.8191  | test_balanced_accuracy: 0.6349  | test_logloss: 0.67972 |  0:02:47s
# epoch 70 | loss: 0.67087 | train_auc: 0.57685 | train_balanced_accuracy: 0.53971 | train_logloss: 0.69471 | test_auc: 0.87876 | test_balanced_accuracy: 0.64956 | test_logloss: 0.6605  |  0:02:49s
# epoch 71 | loss: 0.67218 | train_auc: 0.5793  | train_balanced_accuracy: 0.53969 | train_logloss: 0.69137 | test_auc: 0.90692 | test_balanced_accuracy: 0.64842 | test_logloss: 0.65819 |  0:02:51s
# epoch 72 | loss: 0.67623 | train_auc: 0.58117 | train_balanced_accuracy: 0.53873 | train_logloss: 0.68919 | test_auc: 0.88604 | test_balanced_accuracy: 0.65694 | test_logloss: 0.65436 |  0:02:53s
# epoch 73 | loss: 0.67595 | train_auc: 0.56341 | train_balanced_accuracy: 0.53493 | train_logloss: 0.69501 | test_auc: 0.74908 | test_balanced_accuracy: 0.62613 | test_logloss: 0.68721 |  0:02:56s
# epoch 74 | loss: 0.67273 | train_auc: 0.57673 | train_balanced_accuracy: 0.52075 | train_logloss: 0.70677 | test_auc: 0.88574 | test_balanced_accuracy: 0.55652 | test_logloss: 0.69022 |  0:02:58s
# epoch 75 | loss: 0.67329 | train_auc: 0.57685 | train_balanced_accuracy: 0.52493 | train_logloss: 0.69609 | test_auc: 0.83964 | test_balanced_accuracy: 0.59462 | test_logloss: 0.68435 |  0:03:00s
# epoch 76 | loss: 0.6715  | train_auc: 0.56901 | train_balanced_accuracy: 0.53893 | train_logloss: 0.69437 | test_auc: 0.79998 | test_balanced_accuracy: 0.64424 | test_logloss: 0.6782  |  0:03:03s
# epoch 77 | loss: 0.67066 | train_auc: 0.58379 | train_balanced_accuracy: 0.53292 | train_logloss: 0.69559 | test_auc: 0.90063 | test_balanced_accuracy: 0.60215 | test_logloss: 0.66363 |  0:03:05s
# epoch 78 | loss: 0.67083 | train_auc: 0.57787 | train_balanced_accuracy: 0.53124 | train_logloss: 0.69559 | test_auc: 0.89125 | test_balanced_accuracy: 0.6202  | test_logloss: 0.66232 |  0:03:07s
# epoch 79 | loss: 0.67734 | train_auc: 0.58201 | train_balanced_accuracy: 0.52589 | train_logloss: 0.69756 | test_auc: 0.92126 | test_balanced_accuracy: 0.59424 | test_logloss: 0.66557 |  0:03:09s
# epoch 80 | loss: 0.66993 | train_auc: 0.58346 | train_balanced_accuracy: 0.52972 | train_logloss: 0.69757 | test_auc: 0.90953 | test_balanced_accuracy: 0.59281 | test_logloss: 0.65654 |  0:03:11s
# epoch 81 | loss: 0.67    | train_auc: 0.57647 | train_balanced_accuracy: 0.53354 | train_logloss: 0.69435 | test_auc: 0.84287 | test_balanced_accuracy: 0.60456 | test_logloss: 0.6689  |  0:03:14s
# epoch 82 | loss: 0.67783 | train_auc: 0.56971 | train_balanced_accuracy: 0.52659 | train_logloss: 0.6947  | test_auc: 0.81681 | test_balanced_accuracy: 0.59766 | test_logloss: 0.68024 |  0:03:16s
# epoch 83 | loss: 0.67151 | train_auc: 0.57634 | train_balanced_accuracy: 0.53873 | train_logloss: 0.69169 | test_auc: 0.85869 | test_balanced_accuracy: 0.66267 | test_logloss: 0.65598 |  0:03:18s
# epoch 84 | loss: 0.67061 | train_auc: 0.58551 | train_balanced_accuracy: 0.53778 | train_logloss: 0.6916  | test_auc: 0.9285  | test_balanced_accuracy: 0.64734 | test_logloss: 0.63859 |  0:03:20s
# epoch 85 | loss: 0.67158 | train_auc: 0.57744 | train_balanced_accuracy: 0.53606 | train_logloss: 0.69407 | test_auc: 0.88629 | test_balanced_accuracy: 0.63778 | test_logloss: 0.662   |  0:03:22s
# epoch 86 | loss: 0.67013 | train_auc: 0.5763  | train_balanced_accuracy: 0.52969 | train_logloss: 0.69906 | test_auc: 0.91727 | test_balanced_accuracy: 0.61131 | test_logloss: 0.66459 |  0:03:25s
# epoch 87 | loss: 0.6676  | train_auc: 0.57815 | train_balanced_accuracy: 0.51925 | train_logloss: 0.7129  | test_auc: 0.88879 | test_balanced_accuracy: 0.5632  | test_logloss: 0.68761 |  0:03:27s
# epoch 88 | loss: 0.6716  | train_auc: 0.57732 | train_balanced_accuracy: 0.53461 | train_logloss: 0.69304 | test_auc: 0.86893 | test_balanced_accuracy: 0.6386  | test_logloss: 0.65039 |  0:03:29s
# epoch 89 | loss: 0.672   | train_auc: 0.58134 | train_balanced_accuracy: 0.53386 | train_logloss: 0.69846 | test_auc: 0.89534 | test_balanced_accuracy: 0.6197  | test_logloss: 0.6683  |  0:03:31s
# epoch 90 | loss: 0.67474 | train_auc: 0.58393 | train_balanced_accuracy: 0.5363  | train_logloss: 0.69143 | test_auc: 0.91691 | test_balanced_accuracy: 0.63635 | test_logloss: 0.65881 |  0:03:33s
# epoch 91 | loss: 0.67187 | train_auc: 0.58907 | train_balanced_accuracy: 0.53629 | train_logloss: 0.6897  | test_auc: 0.95409 | test_balanced_accuracy: 0.65485 | test_logloss: 0.64447 |  0:03:36s
# epoch 92 | loss: 0.66792 | train_auc: 0.5894  | train_balanced_accuracy: 0.53651 | train_logloss: 0.6896  | test_auc: 0.93631 | test_balanced_accuracy: 0.65063 | test_logloss: 0.64907 |  0:03:39s
# epoch 93 | loss: 0.6669  | train_auc: 0.58259 | train_balanced_accuracy: 0.53772 | train_logloss: 0.68923 | test_auc: 0.92689 | test_balanced_accuracy: 0.66935 | test_logloss: 0.64904 |  0:03:41s
# epoch 94 | loss: 0.67049 | train_auc: 0.58263 | train_balanced_accuracy: 0.53369 | train_logloss: 0.69178 | test_auc: 0.93513 | test_balanced_accuracy: 0.64208 | test_logloss: 0.64516 |  0:03:43s
# epoch 95 | loss: 0.66908 | train_auc: 0.58365 | train_balanced_accuracy: 0.53695 | train_logloss: 0.69015 | test_auc: 0.91594 | test_balanced_accuracy: 0.63328 | test_logloss: 0.64684 |  0:03:45s
# epoch 96 | loss: 0.66923 | train_auc: 0.58772 | train_balanced_accuracy: 0.53162 | train_logloss: 0.69746 | test_auc: 0.94888 | test_balanced_accuracy: 0.60817 | test_logloss: 0.64353 |  0:03:47s
# epoch 97 | loss: 0.67094 | train_auc: 0.58289 | train_balanced_accuracy: 0.53167 | train_logloss: 0.69182 | test_auc: 0.9195  | test_balanced_accuracy: 0.61206 | test_logloss: 0.66068 |  0:03:50s
# epoch 98 | loss: 0.66899 | train_auc: 0.58685 | train_balanced_accuracy: 0.53576 | train_logloss: 0.69129 | test_auc: 0.94315 | test_balanced_accuracy: 0.64497 | test_logloss: 0.64052 |  0:03:52s
# epoch 99 | loss: 0.66899 | train_auc: 0.5849  | train_balanced_accuracy: 0.53684 | train_logloss: 0.69134 | test_auc: 0.94384 | test_balanced_accuracy: 0.66175 | test_logloss: 0.6372  |  0:03:55s
# Stop training because you reached max_epochs = 100 with best_epoch = 99 and best_test_logloss = 0.6372
# /usr/local/lib/python3.11/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)

# %%
import matplotlib.pyplot as plt

# Lấy lịch sử huấn luyện
history = clf.history

# Accuracy
plt.figure(figsize=(10, 5))
plt.plot(history['train_balanced_accuracy'], label='train accuracy')
plt.plot(history['test_balanced_accuracy'], label='test accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.title('Training and Test Accuracy')
plt.show()

# Loss
plt.figure(figsize=(10, 5))
plt.plot(history['loss'], label='train loss')
plt.plot(history['test_logloss'], label='test loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.title('Training and Test Loss')
plt.show()

# %%
from sklearn.metrics import classification_report
probas = clf.predict_proba(X_test_np)[:, 1]
threshold = 0.5
y_pred_thresh = (probas >= threshold).astype(int)

print(classification_report(y_test.values, y_pred_thresh))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.33      0.49      1579
#            1       0.47      0.99      0.63       929
#
#     accuracy                           0.58      2508
#    macro avg       0.73      0.66      0.56      2508
# weighted avg       0.80      0.58      0.55      2508

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred_thresh)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
# Tính các giá trị cho đường ROC
fpr_tabnet, tpr_tabnet, _ = roc_curve(y_test, probas)
roc_auc_tabnet = auc(fpr_tabnet, tpr_tabnet)

# Vẽ ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr_tabnet, tpr_tabnet, color='darkorange',
         lw=2, label=f'TabNet (AUC = {roc_auc_tabnet:.2f})')

# Đường tham chiếu random guess
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')

# Thiết lập biểu đồ
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - TabNet Classifier')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()
