# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler

# %%
link = 'https://drive.google.com/file/d/1q1IhLHQU7pRIB52_dPURh6dFiSCOmcLG/view?usp=sharing '
path = "https://drive.google.com/uc?export=download&id="+ link.split("/")[-2]
df_train = pd.read_csv(path)
df_train.head()
# Out:
#                 timestamp_TW                                          uuid  \
# 0  2019-05-23 11:45:00+00:00  MlJ4huAZ055iZHo2BJRhGoCRSYYDeIBv7uGFhaqNYCo=
# 1  2019-06-10 21:15:00+00:00  2pM78+2wOAY8l2evtpJS8Q80s14QI3fjcRZb9QFBVn4=
# 2  2019-06-04 16:15:00+00:00  MJPbRkeq6tFmKeTew2v3sxqobPk6QIJZRgC/dsS1Isc=
# 3  2019-05-15 11:30:00+00:00  qo5D63J1RjT9YPTJsFbKo9GAamD5iF6XMdpGMPaE9g4=
# 4  2019-06-09 10:15:00+00:00  uiyyJRVzplrZoBci1aco8pUxwLFge0tPVNhpYJRoqmc=
#
#                                            ucid  \
# 0  w3a6Wk12CqIrUktZei2Z0W3Rf8xdgEdjIW9QX0MWIf8=
# 1  4MP++M0mzDth2XpfseRILPjwOXOAk+Z2oAquU+nEEYE=
# 2  K1JDDj+chCE/ZH5wzdraQHI2j52Nzy0JBJmeLOgq3vc=
# 3  Y+91ladMQTxor3mEVlnYFcmpwmJFyT1HMG+DNySbVZ4=
# 4  bL9LCeyWY9s37YHGGaajw9y6AvwkTvCxHwEL9prznXk=
#
#                                            upid  problem_number  \
# 0  Q5jLvHRQpMUYKZZ6GbotWYCMvkMPq1+yCtpCzTrZW1A=               2
# 1  G4w1QQMbjRT/VptQIZkGYZhO/nkDJiC5ELv+TYfyPHM=               7
# 2  9c2hrY//vjfzCDODz8sOIragypxFG49b/t9S91Krlkg=              14
# 3  ZoE4lwjhMFd9OaWebsWlnK9s1AHSSpuSx8gO7gcplTA=              47
# 4  v4fB2VzIvLxBidz/bupuh6clyMuvR2b8BgSz6PA5UI4=               1
#
#    exercise_problem_repeat_session  is_correct  total_sec_taken  \
# 0                                1        True               29
# 1                                1       False               69
# 2                                1       False               49
# 3                                2        True                9
# 4                                1       False               56
#
#    total_attempt_cnt  used_hint_cnt   points  badges_cnt  is_self_coach  \
# 0                  1              0    28444           7          False
# 1                 19              3   305999          99          False
# 2                  4              2    71162          28          False
# 3                  1              0    47540          13          False
# 4                  2              2  1100969         105          False
#
#    has_student_cnt  belongs_to_class_cnt difficulty learning_stage  cheating
# 0                0                     1       easy     elementary         1
# 1                0                     1       hard     elementary         1
# 2                0                     0       easy         junior         1
# 3                0                     0     normal         junior         1
# 4                0                     1       easy     elementary         1

# %%
print(df_train['cheating'].value_counts())
# Out:
# cheating
# 0    5069
# 1    4960
# Name: count, dtype: int64

# %%
link1 = 'https://drive.google.com/file/d/1muldXGM0lM0hXQHXDyTQNIqjBQPUbSmZ/view?usp=sharing'
path1 = "https://drive.google.com/uc?export=download&id="+ link1.split("/")[-2]
df_test = pd.read_csv(path1)
df_test.head()
# Out:
#                 timestamp_TW                                          uuid  \
# 0  2019-06-04 16:45:00+00:00  +Oo+ob0YK/yFBooA6Nf3OW36y7Gr/b6/ba4a6UME/0A=
# 1  2019-05-21 21:15:00+00:00  mswQBRjmFKewBZnx/zGLKNkgr6Qf5pxv2uge48uqKcU=
# 2  2019-05-31 16:00:00+00:00  QOnOU/aC/jpVXnQanzAbc+E647O5X+nzhGt5VTIcF+c=
# 3  2019-06-11 20:30:00+00:00  J1IpAXiX5/aDRXwY49vUC1iB8B2LBN8Z5Ly4BF+p8ws=
# 4  2019-06-05 22:45:00+00:00  gzAyQpaHDzkY9/IFCbW3JvIolRnpInuj0pJWnSbLwwg=
#
#                                            ucid  \
# 0  3yFVYhjNhMP7tnJJxuCoKfPObXOoeoA5CWP2jeb05pw=
# 1  jImuGvSym6odgRoYw7vgkq4HUbmJ1tDW9fq6bo/yN5s=
# 2  tBr8loWJrEOlzcZDaQL0Q2qMEMUVGJJiWePsXb+7O9U=
# 3  PqQyQvOjvvozBCtlR/0pL8uxhe0K63IPiKYCi1tDG1o=
# 4  yHgHyIJ05U7s8Ak1XnUHY08MP++zF14JXnyie5AL5s0=
#
#                                            upid  problem_number  \
# 0  ER8ng3Tve+gXz0rzE4j8vVQVxJQG9pViFuppcTPCiXs=              16
# 1  EhczsL8/+nNXjaQ9riKSnb9DqC+HCnsSl3iDYW99ixQ=               5
# 2  QGivcV7dEtlX9vq1WVsW9i5jjJ7IeUgUbV8xot9rfbU=               2
# 3  F80i4frwlUPyjWehI764RoG6nzkEcPmKb6+1HcEJXHE=               5
# 4  k7bHRN1JubCEXM7IVXwABfq01n/9pN30eOrL1A8z2yc=              16
#
#    exercise_problem_repeat_session  is_correct  total_sec_taken  \
# 0                                1       False                9
# 1                                1        True               13
# 2                                1        True               39
# 3                                1       False               11
# 4                                2       False               21
#
#    total_attempt_cnt  used_hint_cnt  points  badges_cnt  is_self_coach  \
# 0                  4              1   80647          29          False
# 1                  1              0  239838          35          False
# 2                  1              0  143843          15          False
# 3                  3              0   34960           1          False
# 4                  7              4  219276          70          False
#
#    has_student_cnt  belongs_to_class_cnt difficulty learning_stage  cheating
# 0                0                     1     normal         junior         0
# 1                0                     1       easy     elementary         1
# 2                0                     2     normal     elementary         0
# 3                0                     1       easy     elementary         0
# 4                0                     1       hard     elementary         0

# %%
# One-hot encoding for Difficulty and Learning_stage columns
difficulty_encoded = pd.get_dummies(df_train['difficulty'], prefix='difficulty')
df_train = pd.concat([df_train, difficulty_encoded], axis=1)
df_train = df_train.drop('difficulty', axis=1)
df_train['learning_stage'] = df_train['learning_stage'].replace({'elementary': 1, 'junior': 2, 'senior': 3})

difficulty_encoded1 = pd.get_dummies(df_test['difficulty'], prefix='difficulty')
df_test = pd.concat([df_test, difficulty_encoded1], axis=1)
df_test = df_test.drop('difficulty', axis=1)
df_test['learning_stage'] = df_test['learning_stage'].replace({'elementary': 1, 'junior': 2, 'senior': 3})
# Out:
# /tmp/ipython-input-6-99201639.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_train['learning_stage'] = df_train['learning_stage'].replace({'elementary': 1, 'junior': 2, 'senior': 3})
# /tmp/ipython-input-6-99201639.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_test['learning_stage'] = df_test['learning_stage'].replace({'elementary': 1, 'junior': 2, 'senior': 3})

# %%
df_train['timestamp_TW'] = pd.to_datetime(df_train['timestamp_TW'])
df_train['hour'] = df_train['timestamp_TW'].dt.hour
df_train['minute'] = df_train['timestamp_TW'].dt.minute
df_train['weekday'] = df_train['timestamp_TW'].dt.weekday
df_train['day'] = df_train['timestamp_TW'].dt.day
df_train['month'] = df_train['timestamp_TW'].dt.month

df_test['timestamp_TW'] = pd.to_datetime(df_test['timestamp_TW'])
df_test['hour'] = df_test['timestamp_TW'].dt.hour
df_test['minute'] = df_test['timestamp_TW'].dt.minute
df_test['weekday'] = df_test['timestamp_TW'].dt.weekday
df_test['day'] = df_test['timestamp_TW'].dt.day
df_test['month'] = df_test['timestamp_TW'].dt.month

# %%
df_train =df_train.drop(columns = 'timestamp_TW')
df_test =df_test.drop(columns = 'timestamp_TW')

# %%
df_train = df_train.drop(columns = ['uuid', 'ucid', 'upid'])
df_test = df_test.drop(columns = ['uuid', 'ucid', 'upid'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10029 entries, 0 to 10028
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   problem_number                   10029 non-null  int64
#  1   exercise_problem_repeat_session  10029 non-null  int64
#  2   is_correct                       10029 non-null  bool
#  3   total_sec_taken                  10029 non-null  int64
#  4   total_attempt_cnt                10029 non-null  int64
#  5   used_hint_cnt                    10029 non-null  int64
#  6   points                           10029 non-null  int64
#  7   badges_cnt                       10029 non-null  int64
#  8   is_self_coach                    10029 non-null  bool
#  9   has_student_cnt                  10029 non-null  int64
#  10  belongs_to_class_cnt             10029 non-null  int64
#  11  learning_stage                   10029 non-null  int64
#  12  cheating                         10029 non-null  int64
#  13  difficulty_easy                  10029 non-null  bool
#  14  difficulty_hard                  10029 non-null  bool
#  15  difficulty_normal                10029 non-null  bool
#  16  hour                             10029 non-null  int32
#  17  minute                           10029 non-null  int32
#  18  weekday                          10029 non-null  int32
#  19  day                              10029 non-null  int32
#  20  month                            10029 non-null  int32
# dtypes: bool(5), int32(5), int64(11)
# memory usage: 1.1 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2508 entries, 0 to 2507
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   problem_number                   2508 non-null   int64
#  1   exercise_problem_repeat_session  2508 non-null   int64
#  2   is_correct                       2508 non-null   bool
#  3   total_sec_taken                  2508 non-null   int64
#  4   total_attempt_cnt                2508 non-null   int64
#  5   used_hint_cnt                    2508 non-null   int64
#  6   points                           2508 non-null   int64
#  7   badges_cnt                       2508 non-null   int64
#  8   is_self_coach                    2508 non-null   bool
#  9   has_student_cnt                  2508 non-null   int64
#  10  belongs_to_class_cnt             2508 non-null   int64
#  11  learning_stage                   2508 non-null   int64
#  12  cheating                         2508 non-null   int64
#  13  difficulty_easy                  2508 non-null   bool
#  14  difficulty_hard                  2508 non-null   bool
#  15  difficulty_normal                2508 non-null   bool
#  16  hour                             2508 non-null   int32
#  17  minute                           2508 non-null   int32
#  18  weekday                          2508 non-null   int32
#  19  day                              2508 non-null   int32
#  20  month                            2508 non-null   int32
# dtypes: bool(5), int32(5), int64(11)
# memory usage: 276.9 KB

# %%
X_train = df_train.drop(columns = "cheating")
y_train = df_train["cheating"]
print(X_train.shape)

X_test = df_test.drop(columns="cheating")
y_test = df_test["cheating"]
print(X_test.shape)
# Out:
# (10029, 20)
# (2508, 20)

# %%
# !pip install pytorch_tabnet
# Out:
# Collecting pytorch_tabnet
#   Downloading pytorch_tabnet-4.1.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (2.0.2)
# Requirement already satisfied: scikit_learn>0.21 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (1.6.1)
# Requirement already satisfied: scipy>1.4 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (1.15.3)
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (2.6.0+cu124)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (4.67.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit_learn>0.21->pytorch_tabnet) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit_learn>0.21->pytorch_tabnet) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.3->pytorch_tabnet) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3->pytorch_tabnet) (3.0.2)
# Downloading pytorch_tabnet-4.1.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 658.3 kB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 52.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 48.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 78.7 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, pytorch_tabnet
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pytorch_tabnet-4.1.0

# %%
from pytorch_tabnet.tab_model import TabNetClassifier
import torch

cat_idxs = []
cat_dims = []
cat_emb_dim = []

# Trọng số xử lý mất cân bằng
class_weights = {0: 1, 1: 1}


# Khởi tạo mô hình TabNetClassifier với đầy đủ tham số
clf = TabNetClassifier(
    n_d=16, n_a=16,  # Kích thước decision layer & attention
    n_steps=7, gamma=1.5,  # Số bước và độ tái sử dụng feature
    n_independent=2, n_shared=2,  # Kiểm soát số lớp chung & riêng
    cat_idxs=cat_idxs, cat_emb_dim=cat_emb_dim,  # Embedding categorical
    optimizer_fn=torch.optim.Adam,  # Sử dụng Adam Optimizer
    optimizer_params=dict(lr=0.02),  # Learning rate = 0.01
    scheduler_fn=torch.optim.lr_scheduler.StepLR,
    scheduler_params={"step_size":10, "gamma":0.9},
    mask_type="sparsemax",  # Sử dụng sparsemax cho feature selection
    lambda_sparse=1e-3,  # Điều chỉnh sparsity để chọn lọc feature
    momentum=0.02,  # BatchNorm momentum
    clip_value=2.0,  # Clipping gradient
    verbose=1,  # Hiển thị log
    device_name='auto'
)
# Convert boolean columns to integers (0 or 1)
for col in X_train.select_dtypes(include=['bool']).columns:
    X_train[col] = X_train[col].astype(int)
    X_test[col] = X_test[col].astype(int)

X_train_np = X_train.values  # Chuyển thành NumPy array
X_test_np = X_test.values
y_train_np = y_train.values
y_test_np = y_test.values

# Huấn luyện mô hình
clf.fit(
    X_train_np, y_train_np,
    eval_set=[(X_train_np, y_train_np), (X_test_np, y_test_np)],
    eval_name=['train', 'test'],
    eval_metric=['auc', 'balanced_accuracy', 'logloss'],
    max_epochs=100, patience=60,
    batch_size=512, virtual_batch_size=128,
    num_workers=0,
    weights=class_weights,  # Trọng số cho lớp mất cân bằng
    drop_last=False
)
# Out:
# /usr/local/lib/python3.11/dist-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 0.9731  | train_auc: 0.50584 | train_balanced_accuracy: 0.50157 | train_logloss: 1.50749 | test_auc: 0.42238 | test_balanced_accuracy: 0.48323 | test_logloss: 1.93243 |  0:00:03s
# epoch 1  | loss: 0.73212 | train_auc: 0.50097 | train_balanced_accuracy: 0.49997 | train_logloss: 0.97246 | test_auc: 0.54661 | test_balanced_accuracy: 0.50475 | test_logloss: 1.1144  |  0:00:06s
# epoch 2  | loss: 0.7074  | train_auc: 0.5026  | train_balanced_accuracy: 0.50185 | train_logloss: 0.80456 | test_auc: 0.4682  | test_balanced_accuracy: 0.50906 | test_logloss: 0.92116 |  0:00:08s
# epoch 3  | loss: 0.69    | train_auc: 0.49586 | train_balanced_accuracy: 0.49964 | train_logloss: 0.72638 | test_auc: 0.48757 | test_balanced_accuracy: 0.49019 | test_logloss: 0.78556 |  0:00:11s
# epoch 4  | loss: 0.68902 | train_auc: 0.50021 | train_balanced_accuracy: 0.50068 | train_logloss: 0.71287 | test_auc: 0.57625 | test_balanced_accuracy: 0.5     | test_logloss: 0.75059 |  0:00:13s
# epoch 5  | loss: 0.68943 | train_auc: 0.50844 | train_balanced_accuracy: 0.50251 | train_logloss: 0.70437 | test_auc: 0.59605 | test_balanced_accuracy: 0.50399 | test_logloss: 0.72816 |  0:00:16s
# epoch 6  | loss: 0.68162 | train_auc: 0.50722 | train_balanced_accuracy: 0.50009 | train_logloss: 0.72337 | test_auc: 0.58523 | test_balanced_accuracy: 0.50792 | test_logloss: 0.76408 |  0:00:19s
# epoch 7  | loss: 0.68182 | train_auc: 0.50677 | train_balanced_accuracy: 0.49979 | train_logloss: 0.72619 | test_auc: 0.57837 | test_balanced_accuracy: 0.49946 | test_logloss: 0.77945 |  0:00:22s
# epoch 8  | loss: 0.68373 | train_auc: 0.50733 | train_balanced_accuracy: 0.49959 | train_logloss: 0.71716 | test_auc: 0.57583 | test_balanced_accuracy: 0.4987  | test_logloss: 0.7584  |  0:00:24s
# epoch 9  | loss: 0.68217 | train_auc: 0.50982 | train_balanced_accuracy: 0.49999 | train_logloss: 0.71124 | test_auc: 0.5853  | test_balanced_accuracy: 0.50105 | test_logloss: 0.75033 |  0:00:26s
# epoch 10 | loss: 0.68133 | train_auc: 0.5061  | train_balanced_accuracy: 0.50227 | train_logloss: 0.70721 | test_auc: 0.6004  | test_balanced_accuracy: 0.51613 | test_logloss: 0.72748 |  0:00:29s
# epoch 11 | loss: 0.68119 | train_auc: 0.50865 | train_balanced_accuracy: 0.49986 | train_logloss: 0.70841 | test_auc: 0.58562 | test_balanced_accuracy: 0.50051 | test_logloss: 0.74141 |  0:00:32s
# epoch 12 | loss: 0.68449 | train_auc: 0.51197 | train_balanced_accuracy: 0.50059 | train_logloss: 0.70244 | test_auc: 0.62619 | test_balanced_accuracy: 0.49924 | test_logloss: 0.72748 |  0:00:34s
# epoch 13 | loss: 0.68066 | train_auc: 0.50576 | train_balanced_accuracy: 0.49813 | train_logloss: 0.71148 | test_auc: 0.55324 | test_balanced_accuracy: 0.50101 | test_logloss: 0.74873 |  0:00:37s
# epoch 14 | loss: 0.68384 | train_auc: 0.50625 | train_balanced_accuracy: 0.50028 | train_logloss: 0.70587 | test_auc: 0.52645 | test_balanced_accuracy: 0.50158 | test_logloss: 0.74053 |  0:00:39s
# epoch 15 | loss: 0.68419 | train_auc: 0.49984 | train_balanced_accuracy: 0.50038 | train_logloss: 0.70335 | test_auc: 0.48037 | test_balanced_accuracy: 0.50127 | test_logloss: 0.73697 |  0:00:42s
# epoch 16 | loss: 0.68534 | train_auc: 0.50445 | train_balanced_accuracy: 0.49909 | train_logloss: 0.70157 | test_auc: 0.56196 | test_balanced_accuracy: 0.50203 | test_logloss: 0.72465 |  0:00:45s
# epoch 17 | loss: 0.68186 | train_auc: 0.51036 | train_balanced_accuracy: 0.50041 | train_logloss: 0.70391 | test_auc: 0.4864  | test_balanced_accuracy: 0.49519 | test_logloss: 0.7379  |  0:00:47s
# epoch 18 | loss: 0.68453 | train_auc: 0.5101  | train_balanced_accuracy: 0.50131 | train_logloss: 0.70465 | test_auc: 0.57515 | test_balanced_accuracy: 0.49984 | test_logloss: 0.73467 |  0:00:50s
# epoch 19 | loss: 0.68002 | train_auc: 0.51423 | train_balanced_accuracy: 0.5001  | train_logloss: 0.72137 | test_auc: 0.55483 | test_balanced_accuracy: 0.50063 | test_logloss: 0.77479 |  0:00:52s
# epoch 20 | loss: 0.68493 | train_auc: 0.50998 | train_balanced_accuracy: 0.50228 | train_logloss: 0.69781 | test_auc: 0.49951 | test_balanced_accuracy: 0.50922 | test_logloss: 0.71818 |  0:00:55s
# epoch 21 | loss: 0.68617 | train_auc: 0.51329 | train_balanced_accuracy: 0.50065 | train_logloss: 0.70751 | test_auc: 0.52116 | test_balanced_accuracy: 0.5038  | test_logloss: 0.74709 |  0:00:58s
# epoch 22 | loss: 0.68154 | train_auc: 0.51709 | train_balanced_accuracy: 0.5039  | train_logloss: 0.6959  | test_auc: 0.50439 | test_balanced_accuracy: 0.49735 | test_logloss: 0.71369 |  0:01:00s
# epoch 23 | loss: 0.68352 | train_auc: 0.51553 | train_balanced_accuracy: 0.50469 | train_logloss: 0.69648 | test_auc: 0.50647 | test_balanced_accuracy: 0.5038  | test_logloss: 0.71541 |  0:01:03s
# epoch 24 | loss: 0.68125 | train_auc: 0.52206 | train_balanced_accuracy: 0.50252 | train_logloss: 0.70453 | test_auc: 0.59208 | test_balanced_accuracy: 0.50234 | test_logloss: 0.73742 |  0:01:05s
# epoch 25 | loss: 0.6799  | train_auc: 0.51855 | train_balanced_accuracy: 0.50018 | train_logloss: 0.71069 | test_auc: 0.56374 | test_balanced_accuracy: 0.50063 | test_logloss: 0.75242 |  0:01:07s
# epoch 26 | loss: 0.67731 | train_auc: 0.51704 | train_balanced_accuracy: 0.49988 | train_logloss: 0.71539 | test_auc: 0.59778 | test_balanced_accuracy: 0.50032 | test_logloss: 0.75684 |  0:01:11s
# epoch 27 | loss: 0.68238 | train_auc: 0.50697 | train_balanced_accuracy: 0.4998  | train_logloss: 0.70923 | test_auc: 0.49048 | test_balanced_accuracy: 0.50032 | test_logloss: 0.7515  |  0:01:13s
# epoch 28 | loss: 0.68039 | train_auc: 0.52171 | train_balanced_accuracy: 0.50068 | train_logloss: 0.71147 | test_auc: 0.57175 | test_balanced_accuracy: 0.50095 | test_logloss: 0.75531 |  0:01:16s
# epoch 29 | loss: 0.6806  | train_auc: 0.51888 | train_balanced_accuracy: 0.50082 | train_logloss: 0.70565 | test_auc: 0.63629 | test_balanced_accuracy: 0.50146 | test_logloss: 0.7365  |  0:01:18s
# epoch 30 | loss: 0.68462 | train_auc: 0.51588 | train_balanced_accuracy: 0.50097 | train_logloss: 0.70852 | test_auc: 0.55459 | test_balanced_accuracy: 0.50158 | test_logloss: 0.74797 |  0:01:20s
# epoch 31 | loss: 0.68429 | train_auc: 0.5173  | train_balanced_accuracy: 0.50211 | train_logloss: 0.70397 | test_auc: 0.5626  | test_balanced_accuracy: 0.50079 | test_logloss: 0.7378  |  0:01:24s
# epoch 32 | loss: 0.68236 | train_auc: 0.51732 | train_balanced_accuracy: 0.49925 | train_logloss: 0.70749 | test_auc: 0.58213 | test_balanced_accuracy: 0.49607 | test_logloss: 0.74257 |  0:01:26s
# epoch 33 | loss: 0.67932 | train_auc: 0.52365 | train_balanced_accuracy: 0.5     | train_logloss: 0.70585 | test_auc: 0.58398 | test_balanced_accuracy: 0.5     | test_logloss: 0.74212 |  0:01:28s
# epoch 34 | loss: 0.68249 | train_auc: 0.51351 | train_balanced_accuracy: 0.50029 | train_logloss: 0.70854 | test_auc: 0.47171 | test_balanced_accuracy: 0.49946 | test_logloss: 0.75426 |  0:01:32s
# epoch 35 | loss: 0.68155 | train_auc: 0.50902 | train_balanced_accuracy: 0.50066 | train_logloss: 0.703   | test_auc: 0.54941 | test_balanced_accuracy: 0.50111 | test_logloss: 0.73395 |  0:01:35s
# epoch 36 | loss: 0.68114 | train_auc: 0.50726 | train_balanced_accuracy: 0.50075 | train_logloss: 0.70491 | test_auc: 0.56341 | test_balanced_accuracy: 0.49858 | test_logloss: 0.73984 |  0:01:38s
# epoch 37 | loss: 0.67948 | train_auc: 0.51196 | train_balanced_accuracy: 0.5031  | train_logloss: 0.70405 | test_auc: 0.55588 | test_balanced_accuracy: 0.51226 | test_logloss: 0.73611 |  0:01:40s
# epoch 38 | loss: 0.67889 | train_auc: 0.51508 | train_balanced_accuracy: 0.5011  | train_logloss: 0.72052 | test_auc: 0.56593 | test_balanced_accuracy: 0.49972 | test_logloss: 0.77427 |  0:01:43s
# epoch 39 | loss: 0.68118 | train_auc: 0.5137  | train_balanced_accuracy: 0.50009 | train_logloss: 0.70821 | test_auc: 0.61358 | test_balanced_accuracy: 0.5     | test_logloss: 0.73893 |  0:01:45s
# epoch 40 | loss: 0.68231 | train_auc: 0.51945 | train_balanced_accuracy: 0.50054 | train_logloss: 0.70839 | test_auc: 0.54155 | test_balanced_accuracy: 0.49709 | test_logloss: 0.7486  |  0:01:48s
# epoch 41 | loss: 0.68239 | train_auc: 0.51256 | train_balanced_accuracy: 0.50059 | train_logloss: 0.70568 | test_auc: 0.58945 | test_balanced_accuracy: 0.4987  | test_logloss: 0.7375  |  0:01:51s
# epoch 42 | loss: 0.67934 | train_auc: 0.5178  | train_balanced_accuracy: 0.49987 | train_logloss: 0.7097  | test_auc: 0.58107 | test_balanced_accuracy: 0.49826 | test_logloss: 0.7476  |  0:01:53s
# epoch 43 | loss: 0.67811 | train_auc: 0.51664 | train_balanced_accuracy: 0.49966 | train_logloss: 0.70877 | test_auc: 0.51199 | test_balanced_accuracy: 0.49934 | test_logloss: 0.75059 |  0:01:56s
# epoch 44 | loss: 0.68188 | train_auc: 0.51816 | train_balanced_accuracy: 0.49994 | train_logloss: 0.70165 | test_auc: 0.56151 | test_balanced_accuracy: 0.49405 | test_logloss: 0.73239 |  0:01:58s
# epoch 45 | loss: 0.68012 | train_auc: 0.51717 | train_balanced_accuracy: 0.50043 | train_logloss: 0.70113 | test_auc: 0.5775  | test_balanced_accuracy: 0.48458 | test_logloss: 0.73045 |  0:02:01s
# epoch 46 | loss: 0.68065 | train_auc: 0.5189  | train_balanced_accuracy: 0.50018 | train_logloss: 0.70656 | test_auc: 0.48447 | test_balanced_accuracy: 0.49839 | test_logloss: 0.74868 |  0:02:04s
# epoch 47 | loss: 0.68093 | train_auc: 0.52029 | train_balanced_accuracy: 0.50073 | train_logloss: 0.70261 | test_auc: 0.576   | test_balanced_accuracy: 0.49639 | test_logloss: 0.7346  |  0:02:06s
# epoch 48 | loss: 0.68319 | train_auc: 0.51574 | train_balanced_accuracy: 0.50028 | train_logloss: 0.70493 | test_auc: 0.5645  | test_balanced_accuracy: 0.50063 | test_logloss: 0.73314 |  0:02:08s
# epoch 49 | loss: 0.68163 | train_auc: 0.51935 | train_balanced_accuracy: 0.49996 | train_logloss: 0.7047  | test_auc: 0.57865 | test_balanced_accuracy: 0.49858 | test_logloss: 0.73892 |  0:02:11s
# epoch 50 | loss: 0.68163 | train_auc: 0.52234 | train_balanced_accuracy: 0.4999  | train_logloss: 0.70136 | test_auc: 0.54362 | test_balanced_accuracy: 0.50032 | test_logloss: 0.7327  |  0:02:14s
# epoch 51 | loss: 0.68115 | train_auc: 0.52411 | train_balanced_accuracy: 0.50047 | train_logloss: 0.70129 | test_auc: 0.61214 | test_balanced_accuracy: 0.49921 | test_logloss: 0.72638 |  0:02:17s
# epoch 52 | loss: 0.67982 | train_auc: 0.51896 | train_balanced_accuracy: 0.50138 | train_logloss: 0.70356 | test_auc: 0.46194 | test_balanced_accuracy: 0.49503 | test_logloss: 0.74182 |  0:02:19s
# epoch 53 | loss: 0.68319 | train_auc: 0.51901 | train_balanced_accuracy: 0.5004  | train_logloss: 0.70204 | test_auc: 0.53204 | test_balanced_accuracy: 0.49934 | test_logloss: 0.7324  |  0:02:21s
# epoch 54 | loss: 0.68202 | train_auc: 0.51609 | train_balanced_accuracy: 0.49941 | train_logloss: 0.69981 | test_auc: 0.59893 | test_balanced_accuracy: 0.50409 | test_logloss: 0.7238  |  0:02:24s
# epoch 55 | loss: 0.68243 | train_auc: 0.5224  | train_balanced_accuracy: 0.50018 | train_logloss: 0.69984 | test_auc: 0.47757 | test_balanced_accuracy: 0.49924 | test_logloss: 0.73346 |  0:02:27s
# epoch 56 | loss: 0.68091 | train_auc: 0.52368 | train_balanced_accuracy: 0.49985 | train_logloss: 0.70628 | test_auc: 0.52627 | test_balanced_accuracy: 0.49642 | test_logloss: 0.74847 |  0:02:29s
# epoch 57 | loss: 0.67762 | train_auc: 0.52114 | train_balanced_accuracy: 0.50558 | train_logloss: 0.70495 | test_auc: 0.5466  | test_balanced_accuracy: 0.49373 | test_logloss: 0.74071 |  0:02:32s
# epoch 58 | loss: 0.68458 | train_auc: 0.51353 | train_balanced_accuracy: 0.50047 | train_logloss: 0.70712 | test_auc: 0.55153 | test_balanced_accuracy: 0.49718 | test_logloss: 0.74639 |  0:02:35s
# epoch 59 | loss: 0.68283 | train_auc: 0.50651 | train_balanced_accuracy: 0.49989 | train_logloss: 0.70568 | test_auc: 0.56031 | test_balanced_accuracy: 0.49946 | test_logloss: 0.74109 |  0:02:38s
# epoch 60 | loss: 0.68333 | train_auc: 0.51231 | train_balanced_accuracy: 0.50019 | train_logloss: 0.70214 | test_auc: 0.55088 | test_balanced_accuracy: 0.49892 | test_logloss: 0.7325  |  0:02:41s
# epoch 61 | loss: 0.68004 | train_auc: 0.51738 | train_balanced_accuracy: 0.49978 | train_logloss: 0.7095  | test_auc: 0.54632 | test_balanced_accuracy: 0.50019 | test_logloss: 0.75102 |  0:02:43s
# epoch 62 | loss: 0.68174 | train_auc: 0.51898 | train_balanced_accuracy: 0.50266 | train_logloss: 0.70387 | test_auc: 0.51943 | test_balanced_accuracy: 0.49721 | test_logloss: 0.73816 |  0:02:46s
# epoch 63 | loss: 0.68105 | train_auc: 0.52302 | train_balanced_accuracy: 0.50221 | train_logloss: 0.70517 | test_auc: 0.46945 | test_balanced_accuracy: 0.49769 | test_logloss: 0.74602 |  0:02:48s
# epoch 64 | loss: 0.68238 | train_auc: 0.5165  | train_balanced_accuracy: 0.50048 | train_logloss: 0.70753 | test_auc: 0.49094 | test_balanced_accuracy: 0.49129 | test_logloss: 0.7489  |  0:02:51s
# epoch 65 | loss: 0.68355 | train_auc: 0.51504 | train_balanced_accuracy: 0.50177 | train_logloss: 0.70709 | test_auc: 0.55485 | test_balanced_accuracy: 0.49883 | test_logloss: 0.7457  |  0:02:54s
# epoch 66 | loss: 0.68309 | train_auc: 0.51442 | train_balanced_accuracy: 0.50128 | train_logloss: 0.70518 | test_auc: 0.54202 | test_balanced_accuracy: 0.49864 | test_logloss: 0.7406  |  0:02:56s
# epoch 67 | loss: 0.68232 | train_auc: 0.51065 | train_balanced_accuracy: 0.50102 | train_logloss: 0.7002  | test_auc: 0.52247 | test_balanced_accuracy: 0.49392 | test_logloss: 0.72774 |  0:02:59s
# epoch 68 | loss: 0.68254 | train_auc: 0.51452 | train_balanced_accuracy: 0.50066 | train_logloss: 0.70149 | test_auc: 0.52849 | test_balanced_accuracy: 0.49826 | test_logloss: 0.73257 |  0:03:01s
# epoch 69 | loss: 0.68484 | train_auc: 0.51505 | train_balanced_accuracy: 0.50125 | train_logloss: 0.69963 | test_auc: 0.48055 | test_balanced_accuracy: 0.49601 | test_logloss: 0.72925 |  0:03:04s
# epoch 70 | loss: 0.67981 | train_auc: 0.51905 | train_balanced_accuracy: 0.5     | train_logloss: 0.71483 | test_auc: 0.56735 | test_balanced_accuracy: 0.5     | test_logloss: 0.76496 |  0:03:07s
# epoch 71 | loss: 0.67893 | train_auc: 0.51637 | train_balanced_accuracy: 0.50153 | train_logloss: 0.70416 | test_auc: 0.57937 | test_balanced_accuracy: 0.49687 | test_logloss: 0.73873 |  0:03:09s
# epoch 72 | loss: 0.68343 | train_auc: 0.51875 | train_balanced_accuracy: 0.50126 | train_logloss: 0.70159 | test_auc: 0.57504 | test_balanced_accuracy: 0.49902 | test_logloss: 0.73389 |  0:03:12s
# epoch 73 | loss: 0.67797 | train_auc: 0.51717 | train_balanced_accuracy: 0.50158 | train_logloss: 0.70383 | test_auc: 0.51641 | test_balanced_accuracy: 0.49259 | test_logloss: 0.74156 |  0:03:14s
# epoch 74 | loss: 0.67884 | train_auc: 0.52124 | train_balanced_accuracy: 0.50122 | train_logloss: 0.70565 | test_auc: 0.58544 | test_balanced_accuracy: 0.49671 | test_logloss: 0.74197 |  0:03:17s
# epoch 75 | loss: 0.67947 | train_auc: 0.52093 | train_balanced_accuracy: 0.50029 | train_logloss: 0.70893 | test_auc: 0.5271  | test_balanced_accuracy: 0.49946 | test_logloss: 0.75383 |  0:03:20s
# epoch 76 | loss: 0.68239 | train_auc: 0.52044 | train_balanced_accuracy: 0.50009 | train_logloss: 0.7036  | test_auc: 0.61798 | test_balanced_accuracy: 0.49892 | test_logloss: 0.73749 |  0:03:22s
# epoch 77 | loss: 0.68214 | train_auc: 0.51658 | train_balanced_accuracy: 0.49963 | train_logloss: 0.70502 | test_auc: 0.6275  | test_balanced_accuracy: 0.49896 | test_logloss: 0.73772 |  0:03:25s
# epoch 78 | loss: 0.68188 | train_auc: 0.52369 | train_balanced_accuracy: 0.50046 | train_logloss: 0.69873 | test_auc: 0.57206 | test_balanced_accuracy: 0.49706 | test_logloss: 0.72246 |  0:03:27s
# epoch 79 | loss: 0.68177 | train_auc: 0.52365 | train_balanced_accuracy: 0.5     | train_logloss: 0.70636 | test_auc: 0.56273 | test_balanced_accuracy: 0.5     | test_logloss: 0.74287 |  0:03:30s
# epoch 80 | loss: 0.68106 | train_auc: 0.51575 | train_balanced_accuracy: 0.4998  | train_logloss: 0.70572 | test_auc: 0.55367 | test_balanced_accuracy: 0.5     | test_logloss: 0.74109 |  0:03:33s
# epoch 81 | loss: 0.67964 | train_auc: 0.51015 | train_balanced_accuracy: 0.50039 | train_logloss: 0.70852 | test_auc: 0.55199 | test_balanced_accuracy: 0.5     | test_logloss: 0.75015 |  0:03:35s
# epoch 82 | loss: 0.68136 | train_auc: 0.51867 | train_balanced_accuracy: 0.50195 | train_logloss: 0.70138 | test_auc: 0.54246 | test_balanced_accuracy: 0.4924  | test_logloss: 0.73144 |  0:03:37s
#
# Early stopping occurred at epoch 82 with best_epoch = 22 and best_test_logloss = 0.71369
# /usr/local/lib/python3.11/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)

# %%
import matplotlib.pyplot as plt

# Lấy lịch sử huấn luyện
history = clf.history

# Accuracy
plt.figure(figsize=(10, 5))
plt.plot(history['train_balanced_accuracy'], label='train accuracy')
plt.plot(history['test_balanced_accuracy'], label='test accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.title('Training and Test Accuracy')
plt.show()

# Loss
plt.figure(figsize=(10, 5))
plt.plot(history['loss'], label='train loss')
plt.plot(history['test_logloss'], label='test loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.title('Training and Test Loss')
plt.show()

# %%
from sklearn.metrics import classification_report
probas = clf.predict_proba(X_test_np)[:, 1]
threshold = 0.53
y_pred_thresh = (probas >= threshold).astype(int)

print(classification_report(y_test.values, y_pred_thresh))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.31      0.41      1579
#            1       0.37      0.70      0.48       929
#
#     accuracy                           0.45      2508
#    macro avg       0.50      0.50      0.45      2508
# weighted avg       0.54      0.45      0.44      2508

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred_thresh)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
# Tính các giá trị cho đường ROC
fpr_tabnet, tpr_tabnet, _ = roc_curve(y_test, probas)
roc_auc_tabnet = auc(fpr_tabnet, tpr_tabnet)

# Vẽ ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr_tabnet, tpr_tabnet, color='darkorange',
         lw=2, label=f'TabNet (AUC = {roc_auc_tabnet:.2f})')

# Đường tham chiếu random guess
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')

# Thiết lập biểu đồ
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - TabNet Classifier')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()
