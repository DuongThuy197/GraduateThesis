# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
link = 'https://drive.google.com/file/d/1q1IhLHQU7pRIB52_dPURh6dFiSCOmcLG/view?usp=sharing '
path = "https://drive.google.com/uc?export=download&id="+ link.split("/")[-2]
df_train = pd.read_csv(path)
df_train.head()
# Out:
#                 timestamp_TW                                          uuid  \
# 0  2019-05-23 11:45:00+00:00  MlJ4huAZ055iZHo2BJRhGoCRSYYDeIBv7uGFhaqNYCo=
# 1  2019-06-10 21:15:00+00:00  2pM78+2wOAY8l2evtpJS8Q80s14QI3fjcRZb9QFBVn4=
# 2  2019-06-04 16:15:00+00:00  MJPbRkeq6tFmKeTew2v3sxqobPk6QIJZRgC/dsS1Isc=
# 3  2019-05-15 11:30:00+00:00  qo5D63J1RjT9YPTJsFbKo9GAamD5iF6XMdpGMPaE9g4=
# 4  2019-06-09 10:15:00+00:00  uiyyJRVzplrZoBci1aco8pUxwLFge0tPVNhpYJRoqmc=
#
#                                            ucid  \
# 0  w3a6Wk12CqIrUktZei2Z0W3Rf8xdgEdjIW9QX0MWIf8=
# 1  4MP++M0mzDth2XpfseRILPjwOXOAk+Z2oAquU+nEEYE=
# 2  K1JDDj+chCE/ZH5wzdraQHI2j52Nzy0JBJmeLOgq3vc=
# 3  Y+91ladMQTxor3mEVlnYFcmpwmJFyT1HMG+DNySbVZ4=
# 4  bL9LCeyWY9s37YHGGaajw9y6AvwkTvCxHwEL9prznXk=
#
#                                            upid  problem_number  \
# 0  Q5jLvHRQpMUYKZZ6GbotWYCMvkMPq1+yCtpCzTrZW1A=               2
# 1  G4w1QQMbjRT/VptQIZkGYZhO/nkDJiC5ELv+TYfyPHM=               7
# 2  9c2hrY//vjfzCDODz8sOIragypxFG49b/t9S91Krlkg=              14
# 3  ZoE4lwjhMFd9OaWebsWlnK9s1AHSSpuSx8gO7gcplTA=              47
# 4  v4fB2VzIvLxBidz/bupuh6clyMuvR2b8BgSz6PA5UI4=               1
#
#    exercise_problem_repeat_session  is_correct  total_sec_taken  \
# 0                                1        True               29
# 1                                1       False               69
# 2                                1       False               49
# 3                                2        True                9
# 4                                1       False               56
#
#    total_attempt_cnt  used_hint_cnt   points  badges_cnt  is_self_coach  \
# 0                  1              0    28444           7          False
# 1                 19              3   305999          99          False
# 2                  4              2    71162          28          False
# 3                  1              0    47540          13          False
# 4                  2              2  1100969         105          False
#
#    has_student_cnt  belongs_to_class_cnt difficulty learning_stage  cheating
# 0                0                     1       easy     elementary         1
# 1                0                     1       hard     elementary         1
# 2                0                     0       easy         junior         1
# 3                0                     0     normal         junior         1
# 4                0                     1       easy     elementary         1

# %%
link1 = 'https://drive.google.com/file/d/1muldXGM0lM0hXQHXDyTQNIqjBQPUbSmZ/view?usp=sharing'
path1 = "https://drive.google.com/uc?export=download&id="+ link1.split("/")[-2]
df_test = pd.read_csv(path1)
df_test.head()
# Out:
#                 timestamp_TW                                          uuid  \
# 0  2019-06-04 16:45:00+00:00  +Oo+ob0YK/yFBooA6Nf3OW36y7Gr/b6/ba4a6UME/0A=
# 1  2019-05-21 21:15:00+00:00  mswQBRjmFKewBZnx/zGLKNkgr6Qf5pxv2uge48uqKcU=
# 2  2019-05-31 16:00:00+00:00  QOnOU/aC/jpVXnQanzAbc+E647O5X+nzhGt5VTIcF+c=
# 3  2019-06-11 20:30:00+00:00  J1IpAXiX5/aDRXwY49vUC1iB8B2LBN8Z5Ly4BF+p8ws=
# 4  2019-06-05 22:45:00+00:00  gzAyQpaHDzkY9/IFCbW3JvIolRnpInuj0pJWnSbLwwg=
#
#                                            ucid  \
# 0  3yFVYhjNhMP7tnJJxuCoKfPObXOoeoA5CWP2jeb05pw=
# 1  jImuGvSym6odgRoYw7vgkq4HUbmJ1tDW9fq6bo/yN5s=
# 2  tBr8loWJrEOlzcZDaQL0Q2qMEMUVGJJiWePsXb+7O9U=
# 3  PqQyQvOjvvozBCtlR/0pL8uxhe0K63IPiKYCi1tDG1o=
# 4  yHgHyIJ05U7s8Ak1XnUHY08MP++zF14JXnyie5AL5s0=
#
#                                            upid  problem_number  \
# 0  ER8ng3Tve+gXz0rzE4j8vVQVxJQG9pViFuppcTPCiXs=              16
# 1  EhczsL8/+nNXjaQ9riKSnb9DqC+HCnsSl3iDYW99ixQ=               5
# 2  QGivcV7dEtlX9vq1WVsW9i5jjJ7IeUgUbV8xot9rfbU=               2
# 3  F80i4frwlUPyjWehI764RoG6nzkEcPmKb6+1HcEJXHE=               5
# 4  k7bHRN1JubCEXM7IVXwABfq01n/9pN30eOrL1A8z2yc=              16
#
#    exercise_problem_repeat_session  is_correct  total_sec_taken  \
# 0                                1       False                9
# 1                                1        True               13
# 2                                1        True               39
# 3                                1       False               11
# 4                                2       False               21
#
#    total_attempt_cnt  used_hint_cnt  points  badges_cnt  is_self_coach  \
# 0                  4              1   80647          29          False
# 1                  1              0  239838          35          False
# 2                  1              0  143843          15          False
# 3                  3              0   34960           1          False
# 4                  7              4  219276          70          False
#
#    has_student_cnt  belongs_to_class_cnt difficulty learning_stage  cheating
# 0                0                     1     normal         junior         0
# 1                0                     1       easy     elementary         1
# 2                0                     2     normal     elementary         0
# 3                0                     1       easy     elementary         0
# 4                0                     1       hard     elementary         0

# %%
df_train = df_train.drop(columns = ['uuid', 'ucid', 'upid'])
df_test = df_test.drop(columns = ['uuid', 'ucid', 'upid'])

# %%
difficulty_encoded = pd.get_dummies(df_train['difficulty'], prefix='difficulty')
df_train = pd.concat([df_train, difficulty_encoded], axis=1)
df_train = df_train.drop('difficulty', axis=1)
df_train['learning_stage'] = df_train['learning_stage'].replace({'elementary': 1, 'junior': 2, 'senior': 3})

difficulty_encoded1 = pd.get_dummies(df_test['difficulty'], prefix='difficulty')
df_test = pd.concat([df_test, difficulty_encoded1], axis=1)
df_test = df_test.drop('difficulty', axis=1)
df_test['learning_stage'] = df_test['learning_stage'].replace({'elementary': 1, 'junior': 2, 'senior': 3})
# Out:
# /tmp/ipython-input-5-3845571072.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_train['learning_stage'] = df_train['learning_stage'].replace({'elementary': 1, 'junior': 2, 'senior': 3})
# /tmp/ipython-input-5-3845571072.py:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_test['learning_stage'] = df_test['learning_stage'].replace({'elementary': 1, 'junior': 2, 'senior': 3})

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10029 entries, 0 to 10028
# Data columns (total 17 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   timestamp_TW                     10029 non-null  object
#  1   problem_number                   10029 non-null  int64
#  2   exercise_problem_repeat_session  10029 non-null  int64
#  3   is_correct                       10029 non-null  bool
#  4   total_sec_taken                  10029 non-null  int64
#  5   total_attempt_cnt                10029 non-null  int64
#  6   used_hint_cnt                    10029 non-null  int64
#  7   points                           10029 non-null  int64
#  8   badges_cnt                       10029 non-null  int64
#  9   is_self_coach                    10029 non-null  bool
#  10  has_student_cnt                  10029 non-null  int64
#  11  belongs_to_class_cnt             10029 non-null  int64
#  12  learning_stage                   10029 non-null  int64
#  13  cheating                         10029 non-null  int64
#  14  difficulty_easy                  10029 non-null  bool
#  15  difficulty_hard                  10029 non-null  bool
#  16  difficulty_normal                10029 non-null  bool
# dtypes: bool(5), int64(11), object(1)
# memory usage: 989.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2508 entries, 0 to 2507
# Data columns (total 17 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   timestamp_TW                     2508 non-null   object
#  1   problem_number                   2508 non-null   int64
#  2   exercise_problem_repeat_session  2508 non-null   int64
#  3   is_correct                       2508 non-null   bool
#  4   total_sec_taken                  2508 non-null   int64
#  5   total_attempt_cnt                2508 non-null   int64
#  6   used_hint_cnt                    2508 non-null   int64
#  7   points                           2508 non-null   int64
#  8   badges_cnt                       2508 non-null   int64
#  9   is_self_coach                    2508 non-null   bool
#  10  has_student_cnt                  2508 non-null   int64
#  11  belongs_to_class_cnt             2508 non-null   int64
#  12  learning_stage                   2508 non-null   int64
#  13  cheating                         2508 non-null   int64
#  14  difficulty_easy                  2508 non-null   bool
#  15  difficulty_hard                  2508 non-null   bool
#  16  difficulty_normal                2508 non-null   bool
# dtypes: bool(5), int64(11), object(1)
# memory usage: 247.5+ KB

# %%
df_train['is_correct'] = df_train['is_correct'].astype(int)
df_test['is_correct'] = df_test['is_correct'].astype(int)

# %%
df_train['timestamp_TW'] = pd.to_datetime(df_train['timestamp_TW'])
df_train['hour'] = df_train['timestamp_TW'].dt.hour
df_train['minute'] = df_train['timestamp_TW'].dt.minute
df_train['weekday'] = df_train['timestamp_TW'].dt.weekday
df_train['day'] = df_train['timestamp_TW'].dt.day
df_train['month'] = df_train['timestamp_TW'].dt.month

df_test['timestamp_TW'] = pd.to_datetime(df_test['timestamp_TW'])
df_test['hour'] = df_test['timestamp_TW'].dt.hour
df_test['minute'] = df_test['timestamp_TW'].dt.minute
df_test['weekday'] = df_test['timestamp_TW'].dt.weekday
df_test['day'] = df_test['timestamp_TW'].dt.day
df_test['month'] = df_test['timestamp_TW'].dt.month

# %%
df_train =df_train.drop(columns = 'timestamp_TW')
df_test =df_test.drop(columns = 'timestamp_TW')

# %%
X_train = df_train.drop(columns = "cheating")
y_train = df_train["cheating"]
print(X_train.shape)

X_test = df_test.drop(columns="cheating")
y_test = df_test["cheating"]
print(X_test.shape)
# Out:
# (10029, 20)
# (2508, 20)

# %%
from imblearn.over_sampling import RandomOverSampler
from sklearn.preprocessing import StandardScaler

# Oversampling
ros = RandomOverSampler(random_state=42)
X_over, y_over = ros.fit_resample(X_train, y_train)

# Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_over)

# %%
X_test_scaled = scaler.transform(X_test)

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

param_grid = {
    'learning_rate': [0.15],
    'max_depth': [5],
    'n_estimators': [190],
    'booster': ['gbtree'],
    'min_child_weight': [1],
    'subsample': [1],
    'colsample_bytree': [0.9],
    'colsample_bylevel': [0.6],
    'colsample_bynode': [1]
}

model_xgboost_tuning = xgb.XGBClassifier()
grid_search = GridSearchCV(estimator=model_xgboost_tuning, param_grid=param_grid,
                           cv=5, scoring='recall', n_jobs=-1)
grid_search.fit(X_train_scaled, y_over)

model_xgboost_tuning = grid_search.best_estimator_

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Predict probablility
y_proba = model_xgboost_tuning.predict_proba(X_test_scaled)
y_scores = y_proba[:, 1]

# Classification threshold
threshold = 0.5
y_pred_threshold = (y_scores >= threshold).astype(int)

# Print report
print("📊 Classification Report on test set:")
print(classification_report(y_test, y_pred_threshold))

# Confusion matrix
cm = confusion_matrix(y_test, y_pred_threshold)
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=[0,1], yticklabels=[0,1])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix on test set")
plt.show()
# Out:
# 📊 Classification Report on test set:
#               precision    recall  f1-score   support
#
#            0       0.62      0.49      0.55      1579
#            1       0.36      0.49      0.41       929
#
#     accuracy                           0.49      2508
#    macro avg       0.49      0.49      0.48      2508
# weighted avg       0.52      0.49      0.50      2508

# %%
import lightgbm as lgb
model_lightgbm_tuning = lgb.LGBMClassifier()
# Xây dựng Grid Search với param_grid
param_grid = {
    'learning_rate': [0.2],
    'max_depth': [5],
    'n_estimators': [100],
    'booster': ['gbtree'],
    'min_child_weight': [1],
    'subsample': [1],
    'colsample_bytree': [0.9],
    'colsample_bylevel': [0.6],
    'colsample_bynode': [1]
}
grid_search = GridSearchCV(estimator=model_lightgbm_tuning, param_grid=param_grid, cv=3, scoring='recall', n_jobs=-1)
grid_search.fit(X_train_scaled, y_over)
model_lightgbm_tuning = grid_search.best_estimator_
# Out:
# [LightGBM] [Warning] Unknown parameter: colsample_bylevel
# [LightGBM] [Warning] Unknown parameter: booster
# [LightGBM] [Warning] Unknown parameter: colsample_bylevel
# [LightGBM] [Warning] Unknown parameter: booster
# [LightGBM] [Info] Number of positive: 5069, number of negative: 5069
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001747 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1024
# [LightGBM] [Info] Number of data points in the train set: 10138, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
y_proba_lgbm = model_lightgbm_tuning.predict_proba(X_test_scaled)
y_scores_lgbm = y_proba_lgbm[:, 1]
threshold_lgbm = 0.5
y_pred_threshold_light = (y_scores_lgbm >= threshold_lgbm).astype(int)

print(classification_report(y_test, y_pred_threshold_light))

cm = confusion_matrix(y_test, y_pred_threshold_light)
sns.heatmap(cm, annot = True, fmt = "g")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# [LightGBM] [Warning] Unknown parameter: colsample_bylevel
# [LightGBM] [Warning] Unknown parameter: booster
#               precision    recall  f1-score   support
#
#            0       0.61      0.47      0.53      1579
#            1       0.36      0.50      0.41       929
#
#     accuracy                           0.48      2508
#    macro avg       0.49      0.48      0.47      2508
# weighted avg       0.52      0.48      0.49      2508
# <Axes: >

# %%
from sklearn.ensemble import RandomForestClassifier


param_grid = {
    'max_depth': [20],
    'n_estimators': [220],
    'min_samples_split': [30],
    'min_samples_leaf': [10],
    'max_features': ["sqrt"]
}

model_random_forest = RandomForestClassifier(random_state=42)
model_random_forest_grid_search = GridSearchCV(model_random_forest, param_grid=param_grid, cv=5, scoring='recall', n_jobs=-1)
model_random_forest_grid_search.fit(X_train_scaled, y_over)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [20], 'max_features': ['sqrt'],
#                          'min_samples_leaf': [10], 'min_samples_split': [30],
#                          'n_estimators': [220]},
#              scoring='recall')

# %%
y_proba_rf = model_random_forest_grid_search.predict_proba(X_test_scaled)
y_scores_rf = y_proba_rf[:, 1]
threshold_rf = 0.5
y_pred_threshold_rf = (y_scores_rf >= threshold_rf).astype(int)


print(classification_report(y_test, y_pred_threshold_rf))
cm = confusion_matrix(y_test, y_pred_threshold_rf)
sns.heatmap(cm, annot = True, fmt = "g")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.51      0.57      1579
#            1       0.38      0.50      0.43       929
#
#     accuracy                           0.51      2508
#    macro avg       0.51      0.51      0.50      2508
# weighted avg       0.54      0.51      0.52      2508
# <Axes: >

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
base = DecisionTreeClassifier(max_depth=3)

# Create Grid Search with param_grid
param_grid = {
    'learning_rate': [0.1, 0.15, 0.2],
    'n_estimators': [150, 180, 190, 250],
    'algorithm': ['SAMME', 'SAMME.R'],
    'estimator': [base]
}
model_adaboost = AdaBoostClassifier()
grid_search = GridSearchCV(estimator=model_adaboost, param_grid=param_grid, cv=5, scoring='recall', n_jobs=-1)
grid_search.fit(X_train_scaled, y_over)
model_adaboost = grid_search.best_estimator_
y_proba = model_adaboost.predict_proba(X_test_scaled)
y_scores = y_proba[:, 1]
threshold = 0.5
y_pred_threshold = (y_scores >= threshold).astype(int)

print(classification_report(y_test, y_pred_threshold))

cm = confusion_matrix(y_test, y_pred_threshold)
sns.heatmap(cm, annot = True, fmt = "g")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 60 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'algorithm' parameter of AdaBoostClassifier must be a str among {'SAMME'}. Got 'SAMME.R' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.52262209 0.54256695 0.51828284 0.51887475 0.53741499 0.51512721
#  0.54017672 0.5172982  0.56998059 0.55142029 0.55122286 0.53011832
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.69      0.48      0.57      1579
#            1       0.42      0.63      0.50       929
#
#     accuracy                           0.54      2508
#    macro avg       0.55      0.55      0.53      2508
# weighted avg       0.59      0.54      0.54      2508
# <Axes: >

# %%
from sklearn.metrics import roc_curve, auc

# Tính ROC và AUC cho từng mô hình
fpr_xgb, tpr_xgb, _ = roc_curve(y_test, y_scores)
roc_auc_xgb = auc(fpr_xgb, tpr_xgb)

fpr_lgbm, tpr_lgbm, _ = roc_curve(y_test, y_scores_lgbm)
roc_auc_lgbm = auc(fpr_lgbm, tpr_lgbm)

fpr_rf, tpr_rf, _ = roc_curve(y_test, y_scores_rf)
roc_auc_rf = auc(fpr_rf, tpr_rf)

fpr_ada, tpr_ada, _ = roc_curve(y_test, y_scores)
roc_auc_ada = auc(fpr_ada, tpr_ada)

# Vẽ ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr_xgb, tpr_xgb, label=f'XGBoost (AUC = {roc_auc_xgb:.2f})')
plt.plot(fpr_lgbm, tpr_lgbm, label=f'LightGBM (AUC = {roc_auc_lgbm:.2f})')
plt.plot(fpr_rf, tpr_rf, label=f'Random Forest (AUC = {roc_auc_rf:.2f})')
plt.plot(fpr_ada, tpr_ada, label=f'AdaBoost (AUC = {roc_auc_ada:.2f})')

# Đường tham chiếu random guess
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess (AUC = 0.5)')

# Cài đặt biểu đồ
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve of 4 Models')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()
