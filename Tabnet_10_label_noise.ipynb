# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler

# %%
link = 'https://drive.google.com/file/d/1Mh9f0Kb93hon4K8vmA8DjWcF5Rq3lFcj/view?usp=sharing '
path = "https://drive.google.com/uc?export=download&id="+ link.split("/")[-2]
df_train = pd.read_csv(path)
df_train.head()
# Out:
#                 timestamp_TW                                          uuid  \
# 0  2019-05-23 11:45:00+00:00  MlJ4huAZ055iZHo2BJRhGoCRSYYDeIBv7uGFhaqNYCo=
# 1  2019-06-10 21:15:00+00:00  2pM78+2wOAY8l2evtpJS8Q80s14QI3fjcRZb9QFBVn4=
# 2  2019-06-04 16:15:00+00:00  MJPbRkeq6tFmKeTew2v3sxqobPk6QIJZRgC/dsS1Isc=
# 3  2019-05-15 11:30:00+00:00  qo5D63J1RjT9YPTJsFbKo9GAamD5iF6XMdpGMPaE9g4=
# 4  2019-06-09 10:15:00+00:00  uiyyJRVzplrZoBci1aco8pUxwLFge0tPVNhpYJRoqmc=
#
#                                            ucid  \
# 0  w3a6Wk12CqIrUktZei2Z0W3Rf8xdgEdjIW9QX0MWIf8=
# 1  4MP++M0mzDth2XpfseRILPjwOXOAk+Z2oAquU+nEEYE=
# 2  K1JDDj+chCE/ZH5wzdraQHI2j52Nzy0JBJmeLOgq3vc=
# 3  Y+91ladMQTxor3mEVlnYFcmpwmJFyT1HMG+DNySbVZ4=
# 4  bL9LCeyWY9s37YHGGaajw9y6AvwkTvCxHwEL9prznXk=
#
#                                            upid  problem_number  \
# 0  Q5jLvHRQpMUYKZZ6GbotWYCMvkMPq1+yCtpCzTrZW1A=               2
# 1  G4w1QQMbjRT/VptQIZkGYZhO/nkDJiC5ELv+TYfyPHM=               7
# 2  9c2hrY//vjfzCDODz8sOIragypxFG49b/t9S91Krlkg=              14
# 3  ZoE4lwjhMFd9OaWebsWlnK9s1AHSSpuSx8gO7gcplTA=              47
# 4  v4fB2VzIvLxBidz/bupuh6clyMuvR2b8BgSz6PA5UI4=               1
#
#    exercise_problem_repeat_session  is_correct  total_sec_taken  \
# 0                                1        True               29
# 1                                1       False               69
# 2                                1       False               49
# 3                                2        True                9
# 4                                1       False               56
#
#    total_attempt_cnt  used_hint_cnt   points  badges_cnt  is_self_coach  \
# 0                  1              0    28444           7          False
# 1                 19              3   305999          99          False
# 2                  4              2    71162          28          False
# 3                  1              0    47540          13          False
# 4                  2              2  1100969         105          False
#
#    has_student_cnt  belongs_to_class_cnt difficulty learning_stage  cheating
# 0                0                     1       easy     elementary         0
# 1                0                     1       hard     elementary         0
# 2                0                     0       easy         junior         0
# 3                0                     0     normal         junior         0
# 4                0                     1       easy     elementary         0

# %%
print(df_train['cheating'].value_counts())
# Out:
# cheating
# 0    6149
# 1    3880
# Name: count, dtype: int64

# %%
link1 = 'https://drive.google.com/file/d/1muldXGM0lM0hXQHXDyTQNIqjBQPUbSmZ/view?usp=sharing'
path1 = "https://drive.google.com/uc?export=download&id="+ link1.split("/")[-2]
df_test = pd.read_csv(path1)
df_test.head()
# Out:
#                 timestamp_TW                                          uuid  \
# 0  2019-06-04 16:45:00+00:00  +Oo+ob0YK/yFBooA6Nf3OW36y7Gr/b6/ba4a6UME/0A=
# 1  2019-05-21 21:15:00+00:00  mswQBRjmFKewBZnx/zGLKNkgr6Qf5pxv2uge48uqKcU=
# 2  2019-05-31 16:00:00+00:00  QOnOU/aC/jpVXnQanzAbc+E647O5X+nzhGt5VTIcF+c=
# 3  2019-06-11 20:30:00+00:00  J1IpAXiX5/aDRXwY49vUC1iB8B2LBN8Z5Ly4BF+p8ws=
# 4  2019-06-05 22:45:00+00:00  gzAyQpaHDzkY9/IFCbW3JvIolRnpInuj0pJWnSbLwwg=
#
#                                            ucid  \
# 0  3yFVYhjNhMP7tnJJxuCoKfPObXOoeoA5CWP2jeb05pw=
# 1  jImuGvSym6odgRoYw7vgkq4HUbmJ1tDW9fq6bo/yN5s=
# 2  tBr8loWJrEOlzcZDaQL0Q2qMEMUVGJJiWePsXb+7O9U=
# 3  PqQyQvOjvvozBCtlR/0pL8uxhe0K63IPiKYCi1tDG1o=
# 4  yHgHyIJ05U7s8Ak1XnUHY08MP++zF14JXnyie5AL5s0=
#
#                                            upid  problem_number  \
# 0  ER8ng3Tve+gXz0rzE4j8vVQVxJQG9pViFuppcTPCiXs=              16
# 1  EhczsL8/+nNXjaQ9riKSnb9DqC+HCnsSl3iDYW99ixQ=               5
# 2  QGivcV7dEtlX9vq1WVsW9i5jjJ7IeUgUbV8xot9rfbU=               2
# 3  F80i4frwlUPyjWehI764RoG6nzkEcPmKb6+1HcEJXHE=               5
# 4  k7bHRN1JubCEXM7IVXwABfq01n/9pN30eOrL1A8z2yc=              16
#
#    exercise_problem_repeat_session  is_correct  total_sec_taken  \
# 0                                1       False                9
# 1                                1        True               13
# 2                                1        True               39
# 3                                1       False               11
# 4                                2       False               21
#
#    total_attempt_cnt  used_hint_cnt  points  badges_cnt  is_self_coach  \
# 0                  4              1   80647          29          False
# 1                  1              0  239838          35          False
# 2                  1              0  143843          15          False
# 3                  3              0   34960           1          False
# 4                  7              4  219276          70          False
#
#    has_student_cnt  belongs_to_class_cnt difficulty learning_stage  cheating
# 0                0                     1     normal         junior         0
# 1                0                     1       easy     elementary         1
# 2                0                     2     normal     elementary         0
# 3                0                     1       easy     elementary         0
# 4                0                     1       hard     elementary         0

# %%
# One-hot encoding for Difficulty and Learning_stage columns
difficulty_encoded = pd.get_dummies(df_train['difficulty'], prefix='difficulty')
df_train = pd.concat([df_train, difficulty_encoded], axis=1)
df_train = df_train.drop('difficulty', axis=1)
df_train['learning_stage'] = df_train['learning_stage'].replace({'elementary': 1, 'junior': 2, 'senior': 3})

difficulty_encoded1 = pd.get_dummies(df_test['difficulty'], prefix='difficulty')
df_test = pd.concat([df_test, difficulty_encoded1], axis=1)
df_test = df_test.drop('difficulty', axis=1)
df_test['learning_stage'] = df_test['learning_stage'].replace({'elementary': 1, 'junior': 2, 'senior': 3})
# Out:
# <ipython-input-6-efca2904d212>:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_train['learning_stage'] = df_train['learning_stage'].replace({'elementary': 1, 'junior': 2, 'senior': 3})
# <ipython-input-6-efca2904d212>:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_test['learning_stage'] = df_test['learning_stage'].replace({'elementary': 1, 'junior': 2, 'senior': 3})

# %%
df_train['timestamp_TW'] = pd.to_datetime(df_train['timestamp_TW'])
df_train['hour'] = df_train['timestamp_TW'].dt.hour
df_train['minute'] = df_train['timestamp_TW'].dt.minute
df_train['weekday'] = df_train['timestamp_TW'].dt.weekday
df_train['day'] = df_train['timestamp_TW'].dt.day
df_train['month'] = df_train['timestamp_TW'].dt.month

df_test['timestamp_TW'] = pd.to_datetime(df_test['timestamp_TW'])
df_test['hour'] = df_test['timestamp_TW'].dt.hour
df_test['minute'] = df_test['timestamp_TW'].dt.minute
df_test['weekday'] = df_test['timestamp_TW'].dt.weekday
df_test['day'] = df_test['timestamp_TW'].dt.day
df_test['month'] = df_test['timestamp_TW'].dt.month

# %%
df_train =df_train.drop(columns = 'timestamp_TW')
df_test =df_test.drop(columns = 'timestamp_TW')

# %%
df_train = df_train.drop(columns = ['uuid', 'ucid', 'upid'])
df_test = df_test.drop(columns = ['uuid', 'ucid', 'upid'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10029 entries, 0 to 10028
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   problem_number                   10029 non-null  int64
#  1   exercise_problem_repeat_session  10029 non-null  int64
#  2   is_correct                       10029 non-null  bool
#  3   total_sec_taken                  10029 non-null  int64
#  4   total_attempt_cnt                10029 non-null  int64
#  5   used_hint_cnt                    10029 non-null  int64
#  6   points                           10029 non-null  int64
#  7   badges_cnt                       10029 non-null  int64
#  8   is_self_coach                    10029 non-null  bool
#  9   has_student_cnt                  10029 non-null  int64
#  10  belongs_to_class_cnt             10029 non-null  int64
#  11  learning_stage                   10029 non-null  int64
#  12  cheating                         10029 non-null  int64
#  13  difficulty_easy                  10029 non-null  bool
#  14  difficulty_hard                  10029 non-null  bool
#  15  difficulty_normal                10029 non-null  bool
#  16  hour                             10029 non-null  int32
#  17  minute                           10029 non-null  int32
#  18  weekday                          10029 non-null  int32
#  19  day                              10029 non-null  int32
#  20  month                            10029 non-null  int32
# dtypes: bool(5), int32(5), int64(11)
# memory usage: 1.1 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2508 entries, 0 to 2507
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   problem_number                   2508 non-null   int64
#  1   exercise_problem_repeat_session  2508 non-null   int64
#  2   is_correct                       2508 non-null   bool
#  3   total_sec_taken                  2508 non-null   int64
#  4   total_attempt_cnt                2508 non-null   int64
#  5   used_hint_cnt                    2508 non-null   int64
#  6   points                           2508 non-null   int64
#  7   badges_cnt                       2508 non-null   int64
#  8   is_self_coach                    2508 non-null   bool
#  9   has_student_cnt                  2508 non-null   int64
#  10  belongs_to_class_cnt             2508 non-null   int64
#  11  learning_stage                   2508 non-null   int64
#  12  cheating                         2508 non-null   int64
#  13  difficulty_easy                  2508 non-null   bool
#  14  difficulty_hard                  2508 non-null   bool
#  15  difficulty_normal                2508 non-null   bool
#  16  hour                             2508 non-null   int32
#  17  minute                           2508 non-null   int32
#  18  weekday                          2508 non-null   int32
#  19  day                              2508 non-null   int32
#  20  month                            2508 non-null   int32
# dtypes: bool(5), int32(5), int64(11)
# memory usage: 276.9 KB

# %%
X_train = df_train.drop(columns = "cheating")
y_train = df_train["cheating"]
print(X_train.shape)

X_test = df_test.drop(columns="cheating")
y_test = df_test["cheating"]
print(X_test.shape)
# Out:
# (10029, 20)
# (2508, 20)

# %%
# !pip install pytorch_tabnet
# Out:
# Collecting pytorch_tabnet
#   Downloading pytorch_tabnet-4.1.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (1.26.4)
# Requirement already satisfied: scikit_learn>0.21 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (1.6.1)
# Requirement already satisfied: scipy>1.4 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (1.13.1)
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (2.5.1+cu124)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (4.67.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit_learn>0.21->pytorch_tabnet) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit_learn>0.21->pytorch_tabnet) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.3->pytorch_tabnet) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3->pytorch_tabnet) (3.0.2)
# Downloading pytorch_tabnet-4.1.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 38.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 25.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 27.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 19.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, pytorch_tabnet
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pytorch_tabnet-4.1.0

# %%
from pytorch_tabnet.tab_model import TabNetClassifier
import torch

cat_idxs = []
cat_dims = []
cat_emb_dim = []

# Trọng số xử lý mất cân bằng
class_weights = {0: 1, 1: 1.6}


# Khởi tạo mô hình TabNetClassifier với đầy đủ tham số
clf = TabNetClassifier(
    n_d=16, n_a=16,  # Kích thước decision layer & attention
    n_steps=7, gamma=1.5,  # Số bước và độ tái sử dụng feature
    n_independent=2, n_shared=2,  # Kiểm soát số lớp chung & riêng
    cat_idxs=cat_idxs, cat_emb_dim=cat_emb_dim,  # Embedding categorical
    optimizer_fn=torch.optim.Adam,  # Sử dụng Adam Optimizer
    optimizer_params=dict(lr=0.02),  # Learning rate = 0.01
    scheduler_fn=torch.optim.lr_scheduler.StepLR,
    scheduler_params={"step_size":10, "gamma":0.9},
    mask_type="sparsemax",  # Sử dụng sparsemax cho feature selection
    lambda_sparse=1e-3,  # Điều chỉnh sparsity để chọn lọc feature
    momentum=0.02,  # BatchNorm momentum
    clip_value=2.0,  # Clipping gradient
    verbose=1,  # Hiển thị log
    device_name='auto'
)
# Convert boolean columns to integers (0 or 1)
for col in X_train.select_dtypes(include=['bool']).columns:
    X_train[col] = X_train[col].astype(int)
    X_test[col] = X_test[col].astype(int)

X_train_np = X_train.values  # Chuyển thành NumPy array
X_test_np = X_test.values
y_train_np = y_train.values
y_test_np = y_test.values

# Huấn luyện mô hình
clf.fit(
    X_train_np, y_train_np,
    eval_set=[(X_train_np, y_train_np), (X_test_np, y_test_np)],
    eval_name=['train', 'test'],
    eval_metric=['auc', 'balanced_accuracy', 'logloss'],
    max_epochs=100, patience=60,
    batch_size=512, virtual_batch_size=128,
    num_workers=0,
    weights=class_weights,  # Trọng số cho lớp mất cân bằng
    drop_last=False
)
# Out:
# /usr/local/lib/python3.11/dist-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 1.009   | train_auc: 0.52165 | train_balanced_accuracy: 0.51225 | train_logloss: 1.70866 | test_auc: 0.52552 | test_balanced_accuracy: 0.52255 | test_logloss: 1.73439 |  0:00:07s
# epoch 1  | loss: 0.67931 | train_auc: 0.59807 | train_balanced_accuracy: 0.56658 | train_logloss: 0.85999 | test_auc: 0.61989 | test_balanced_accuracy: 0.592   | test_logloss: 0.87771 |  0:00:10s
# epoch 2  | loss: 0.66325 | train_auc: 0.64395 | train_balanced_accuracy: 0.60636 | train_logloss: 0.69181 | test_auc: 0.67844 | test_balanced_accuracy: 0.63849 | test_logloss: 0.67841 |  0:00:12s
# epoch 3  | loss: 0.63454 | train_auc: 0.62767 | train_balanced_accuracy: 0.59371 | train_logloss: 0.7047  | test_auc: 0.67095 | test_balanced_accuracy: 0.62751 | test_logloss: 0.68665 |  0:00:14s
# epoch 4  | loss: 0.59325 | train_auc: 0.63719 | train_balanced_accuracy: 0.58808 | train_logloss: 0.67931 | test_auc: 0.68751 | test_balanced_accuracy: 0.62608 | test_logloss: 0.65567 |  0:00:17s
# epoch 5  | loss: 0.56028 | train_auc: 0.75958 | train_balanced_accuracy: 0.70004 | train_logloss: 0.61484 | test_auc: 0.82582 | test_balanced_accuracy: 0.75473 | test_logloss: 0.57845 |  0:00:20s
# epoch 6  | loss: 0.52338 | train_auc: 0.7708  | train_balanced_accuracy: 0.66021 | train_logloss: 0.57714 | test_auc: 0.84162 | test_balanced_accuracy: 0.70074 | test_logloss: 0.50544 |  0:00:22s
# epoch 7  | loss: 0.48688 | train_auc: 0.80398 | train_balanced_accuracy: 0.63659 | train_logloss: 0.56063 | test_auc: 0.89554 | test_balanced_accuracy: 0.68536 | test_logloss: 0.46919 |  0:00:24s
# epoch 8  | loss: 0.51126 | train_auc: 0.81095 | train_balanced_accuracy: 0.69543 | train_logloss: 0.53349 | test_auc: 0.9056  | test_balanced_accuracy: 0.75739 | test_logloss: 0.44628 |  0:00:26s
# epoch 9  | loss: 0.48733 | train_auc: 0.8605  | train_balanced_accuracy: 0.75337 | train_logloss: 0.47771 | test_auc: 0.95726 | test_balanced_accuracy: 0.82109 | test_logloss: 0.35938 |  0:00:29s
# epoch 10 | loss: 0.47446 | train_auc: 0.86079 | train_balanced_accuracy: 0.74982 | train_logloss: 0.47924 | test_auc: 0.9582  | test_balanced_accuracy: 0.82467 | test_logloss: 0.37725 |  0:00:32s
# epoch 11 | loss: 0.4534  | train_auc: 0.86798 | train_balanced_accuracy: 0.7824  | train_logloss: 0.45517 | test_auc: 0.9668  | test_balanced_accuracy: 0.86025 | test_logloss: 0.32841 |  0:00:34s
# epoch 12 | loss: 0.4736  | train_auc: 0.86861 | train_balanced_accuracy: 0.7539  | train_logloss: 0.47048 | test_auc: 0.96882 | test_balanced_accuracy: 0.82337 | test_logloss: 0.35063 |  0:00:36s
# epoch 13 | loss: 0.45094 | train_auc: 0.8703  | train_balanced_accuracy: 0.81456 | train_logloss: 0.43793 | test_auc: 0.97632 | test_balanced_accuracy: 0.90831 | test_logloss: 0.29535 |  0:00:39s
# epoch 14 | loss: 0.44947 | train_auc: 0.86825 | train_balanced_accuracy: 0.71441 | train_logloss: 0.49819 | test_auc: 0.97174 | test_balanced_accuracy: 0.78307 | test_logloss: 0.36591 |  0:00:41s
# epoch 15 | loss: 0.4453  | train_auc: 0.84316 | train_balanced_accuracy: 0.63265 | train_logloss: 0.58469 | test_auc: 0.94284 | test_balanced_accuracy: 0.6658  | test_logloss: 0.4604  |  0:00:44s
# epoch 16 | loss: 0.44394 | train_auc: 0.84849 | train_balanced_accuracy: 0.71927 | train_logloss: 0.4988  | test_auc: 0.9521  | test_balanced_accuracy: 0.78728 | test_logloss: 0.39127 |  0:00:46s
# epoch 17 | loss: 0.42981 | train_auc: 0.8664  | train_balanced_accuracy: 0.78985 | train_logloss: 0.43768 | test_auc: 0.9683  | test_balanced_accuracy: 0.87532 | test_logloss: 0.29647 |  0:00:48s
# epoch 18 | loss: 0.42392 | train_auc: 0.86514 | train_balanced_accuracy: 0.77967 | train_logloss: 0.4412  | test_auc: 0.96696 | test_balanced_accuracy: 0.85959 | test_logloss: 0.29373 |  0:00:50s
# epoch 19 | loss: 0.44006 | train_auc: 0.87782 | train_balanced_accuracy: 0.85483 | train_logloss: 0.40028 | test_auc: 0.98826 | test_balanced_accuracy: 0.96093 | test_logloss: 0.24346 |  0:00:53s
# epoch 20 | loss: 0.41198 | train_auc: 0.87447 | train_balanced_accuracy: 0.83634 | train_logloss: 0.40348 | test_auc: 0.98539 | test_balanced_accuracy: 0.93325 | test_logloss: 0.21365 |  0:00:56s
# epoch 21 | loss: 0.42318 | train_auc: 0.87401 | train_balanced_accuracy: 0.75906 | train_logloss: 0.45718 | test_auc: 0.97972 | test_balanced_accuracy: 0.83325 | test_logloss: 0.34282 |  0:00:58s
# epoch 22 | loss: 0.4191  | train_auc: 0.87241 | train_balanced_accuracy: 0.70641 | train_logloss: 0.48549 | test_auc: 0.97769 | test_balanced_accuracy: 0.77249 | test_logloss: 0.3793  |  0:01:00s
# epoch 23 | loss: 0.40651 | train_auc: 0.8757  | train_balanced_accuracy: 0.77364 | train_logloss: 0.43425 | test_auc: 0.98487 | test_balanced_accuracy: 0.85177 | test_logloss: 0.29152 |  0:01:02s
# epoch 24 | loss: 0.40301 | train_auc: 0.87569 | train_balanced_accuracy: 0.77006 | train_logloss: 0.43899 | test_auc: 0.98495 | test_balanced_accuracy: 0.84844 | test_logloss: 0.3095  |  0:01:04s
# epoch 25 | loss: 0.41223 | train_auc: 0.87003 | train_balanced_accuracy: 0.73562 | train_logloss: 0.4682  | test_auc: 0.97608 | test_balanced_accuracy: 0.80586 | test_logloss: 0.33244 |  0:01:07s
# epoch 26 | loss: 0.4075  | train_auc: 0.87701 | train_balanced_accuracy: 0.82168 | train_logloss: 0.40867 | test_auc: 0.98546 | test_balanced_accuracy: 0.92671 | test_logloss: 0.24993 |  0:01:10s
# epoch 27 | loss: 0.41376 | train_auc: 0.88062 | train_balanced_accuracy: 0.78256 | train_logloss: 0.42163 | test_auc: 0.9855  | test_balanced_accuracy: 0.86133 | test_logloss: 0.27495 |  0:01:12s
# epoch 28 | loss: 0.42374 | train_auc: 0.87372 | train_balanced_accuracy: 0.72878 | train_logloss: 0.47326 | test_auc: 0.97392 | test_balanced_accuracy: 0.79969 | test_logloss: 0.36406 |  0:01:14s
# epoch 29 | loss: 0.40675 | train_auc: 0.8772  | train_balanced_accuracy: 0.78055 | train_logloss: 0.43234 | test_auc: 0.9796  | test_balanced_accuracy: 0.85677 | test_logloss: 0.29512 |  0:01:17s
# epoch 30 | loss: 0.41687 | train_auc: 0.87682 | train_balanced_accuracy: 0.76242 | train_logloss: 0.44809 | test_auc: 0.9775  | test_balanced_accuracy: 0.8335  | test_logloss: 0.32686 |  0:01:19s
# epoch 31 | loss: 0.42795 | train_auc: 0.86166 | train_balanced_accuracy: 0.68446 | train_logloss: 0.511   | test_auc: 0.96556 | test_balanced_accuracy: 0.74299 | test_logloss: 0.41785 |  0:01:22s
# epoch 32 | loss: 0.42287 | train_auc: 0.87265 | train_balanced_accuracy: 0.84289 | train_logloss: 0.40266 | test_auc: 0.98307 | test_balanced_accuracy: 0.94725 | test_logloss: 0.23468 |  0:01:24s
# epoch 33 | loss: 0.40845 | train_auc: 0.87614 | train_balanced_accuracy: 0.77892 | train_logloss: 0.43166 | test_auc: 0.97948 | test_balanced_accuracy: 0.85186 | test_logloss: 0.29115 |  0:01:26s
# epoch 34 | loss: 0.40785 | train_auc: 0.87862 | train_balanced_accuracy: 0.7968  | train_logloss: 0.41744 | test_auc: 0.98731 | test_balanced_accuracy: 0.88827 | test_logloss: 0.27085 |  0:01:29s
# epoch 35 | loss: 0.40232 | train_auc: 0.88054 | train_balanced_accuracy: 0.76089 | train_logloss: 0.43945 | test_auc: 0.98591 | test_balanced_accuracy: 0.83388 | test_logloss: 0.29238 |  0:01:31s
# epoch 36 | loss: 0.38874 | train_auc: 0.85851 | train_balanced_accuracy: 0.70636 | train_logloss: 0.4971  | test_auc: 0.95616 | test_balanced_accuracy: 0.77426 | test_logloss: 0.39229 |  0:01:34s
# epoch 37 | loss: 0.40429 | train_auc: 0.85941 | train_balanced_accuracy: 0.67442 | train_logloss: 0.5128  | test_auc: 0.95925 | test_balanced_accuracy: 0.72845 | test_logloss: 0.41917 |  0:01:36s
# epoch 38 | loss: 0.42706 | train_auc: 0.86349 | train_balanced_accuracy: 0.75526 | train_logloss: 0.46006 | test_auc: 0.96656 | test_balanced_accuracy: 0.82406 | test_logloss: 0.32132 |  0:01:38s
# epoch 39 | loss: 0.41074 | train_auc: 0.86594 | train_balanced_accuracy: 0.80057 | train_logloss: 0.44392 | test_auc: 0.96845 | test_balanced_accuracy: 0.88998 | test_logloss: 0.28968 |  0:01:41s
# epoch 40 | loss: 0.4164  | train_auc: 0.86232 | train_balanced_accuracy: 0.70031 | train_logloss: 0.49822 | test_auc: 0.96444 | test_balanced_accuracy: 0.76429 | test_logloss: 0.39896 |  0:01:43s
# epoch 41 | loss: 0.40942 | train_auc: 0.86628 | train_balanced_accuracy: 0.75743 | train_logloss: 0.46062 | test_auc: 0.96771 | test_balanced_accuracy: 0.82362 | test_logloss: 0.33648 |  0:01:46s
# epoch 42 | loss: 0.39822 | train_auc: 0.87698 | train_balanced_accuracy: 0.77453 | train_logloss: 0.43288 | test_auc: 0.98253 | test_balanced_accuracy: 0.85313 | test_logloss: 0.28412 |  0:01:48s
# epoch 43 | loss: 0.3986  | train_auc: 0.8748  | train_balanced_accuracy: 0.72909 | train_logloss: 0.47312 | test_auc: 0.98072 | test_balanced_accuracy: 0.79864 | test_logloss: 0.33404 |  0:01:50s
# epoch 44 | loss: 0.40417 | train_auc: 0.87881 | train_balanced_accuracy: 0.711   | train_logloss: 0.4765  | test_auc: 0.98483 | test_balanced_accuracy: 0.78294 | test_logloss: 0.35879 |  0:01:53s
# epoch 45 | loss: 0.40452 | train_auc: 0.88085 | train_balanced_accuracy: 0.76919 | train_logloss: 0.43949 | test_auc: 0.98859 | test_balanced_accuracy: 0.84484 | test_logloss: 0.3003  |  0:01:56s
# epoch 46 | loss: 0.40506 | train_auc: 0.88139 | train_balanced_accuracy: 0.7679  | train_logloss: 0.43632 | test_auc: 0.98803 | test_balanced_accuracy: 0.83645 | test_logloss: 0.30265 |  0:01:59s
# epoch 47 | loss: 0.39649 | train_auc: 0.87098 | train_balanced_accuracy: 0.73326 | train_logloss: 0.47681 | test_auc: 0.97748 | test_balanced_accuracy: 0.80254 | test_logloss: 0.35313 |  0:02:01s
# epoch 48 | loss: 0.40023 | train_auc: 0.87872 | train_balanced_accuracy: 0.82695 | train_logloss: 0.39954 | test_auc: 0.98564 | test_balanced_accuracy: 0.92902 | test_logloss: 0.22968 |  0:02:04s
# epoch 49 | loss: 0.40413 | train_auc: 0.88295 | train_balanced_accuracy: 0.77738 | train_logloss: 0.43039 | test_auc: 0.98703 | test_balanced_accuracy: 0.85604 | test_logloss: 0.28856 |  0:02:06s
# epoch 50 | loss: 0.39265 | train_auc: 0.87878 | train_balanced_accuracy: 0.72687 | train_logloss: 0.47358 | test_auc: 0.98238 | test_balanced_accuracy: 0.79801 | test_logloss: 0.35928 |  0:02:08s
# epoch 51 | loss: 0.39941 | train_auc: 0.88    | train_balanced_accuracy: 0.80105 | train_logloss: 0.41209 | test_auc: 0.9878  | test_balanced_accuracy: 0.89359 | test_logloss: 0.25985 |  0:02:11s
# epoch 52 | loss: 0.41143 | train_auc: 0.86406 | train_balanced_accuracy: 0.7958  | train_logloss: 0.42906 | test_auc: 0.96943 | test_balanced_accuracy: 0.88346 | test_logloss: 0.28781 |  0:02:14s
# epoch 53 | loss: 0.45032 | train_auc: 0.87355 | train_balanced_accuracy: 0.72141 | train_logloss: 0.46955 | test_auc: 0.98122 | test_balanced_accuracy: 0.78905 | test_logloss: 0.34186 |  0:02:16s
# epoch 54 | loss: 0.4068  | train_auc: 0.86339 | train_balanced_accuracy: 0.78117 | train_logloss: 0.44141 | test_auc: 0.96913 | test_balanced_accuracy: 0.87076 | test_logloss: 0.29448 |  0:02:18s
# epoch 55 | loss: 0.4574  | train_auc: 0.8485  | train_balanced_accuracy: 0.74729 | train_logloss: 0.47338 | test_auc: 0.94826 | test_balanced_accuracy: 0.82058 | test_logloss: 0.34748 |  0:02:20s
# epoch 56 | loss: 0.4341  | train_auc: 0.8721  | train_balanced_accuracy: 0.75359 | train_logloss: 0.45552 | test_auc: 0.9776  | test_balanced_accuracy: 0.82549 | test_logloss: 0.32338 |  0:02:23s
# epoch 57 | loss: 0.41062 | train_auc: 0.88073 | train_balanced_accuracy: 0.75675 | train_logloss: 0.45207 | test_auc: 0.98654 | test_balanced_accuracy: 0.8304  | test_logloss: 0.33107 |  0:02:26s
# epoch 58 | loss: 0.3948  | train_auc: 0.87657 | train_balanced_accuracy: 0.76793 | train_logloss: 0.43582 | test_auc: 0.98584 | test_balanced_accuracy: 0.84579 | test_logloss: 0.2878  |  0:02:28s
# epoch 59 | loss: 0.39819 | train_auc: 0.87766 | train_balanced_accuracy: 0.74027 | train_logloss: 0.45708 | test_auc: 0.98312 | test_balanced_accuracy: 0.81295 | test_logloss: 0.32825 |  0:02:30s
# epoch 60 | loss: 0.39214 | train_auc: 0.86954 | train_balanced_accuracy: 0.67031 | train_logloss: 0.52464 | test_auc: 0.97335 | test_balanced_accuracy: 0.7182  | test_logloss: 0.42373 |  0:02:32s
# epoch 61 | loss: 0.38455 | train_auc: 0.88082 | train_balanced_accuracy: 0.76316 | train_logloss: 0.4427  | test_auc: 0.98937 | test_balanced_accuracy: 0.83705 | test_logloss: 0.28871 |  0:02:34s
# epoch 62 | loss: 0.39781 | train_auc: 0.88074 | train_balanced_accuracy: 0.75945 | train_logloss: 0.44147 | test_auc: 0.9899  | test_balanced_accuracy: 0.83154 | test_logloss: 0.29513 |  0:02:37s
# epoch 63 | loss: 0.39825 | train_auc: 0.88224 | train_balanced_accuracy: 0.77475 | train_logloss: 0.43281 | test_auc: 0.9883  | test_balanced_accuracy: 0.85342 | test_logloss: 0.29513 |  0:02:40s
# epoch 64 | loss: 0.40554 | train_auc: 0.88003 | train_balanced_accuracy: 0.79102 | train_logloss: 0.41949 | test_auc: 0.98801 | test_balanced_accuracy: 0.87678 | test_logloss: 0.27313 |  0:02:42s
# epoch 65 | loss: 0.38969 | train_auc: 0.88179 | train_balanced_accuracy: 0.78112 | train_logloss: 0.42393 | test_auc: 0.98841 | test_balanced_accuracy: 0.85946 | test_logloss: 0.2829  |  0:02:44s
# epoch 66 | loss: 0.39659 | train_auc: 0.88444 | train_balanced_accuracy: 0.7679  | train_logloss: 0.4409  | test_auc: 0.98496 | test_balanced_accuracy: 0.83515 | test_logloss: 0.31719 |  0:02:47s
# epoch 67 | loss: 0.39709 | train_auc: 0.88399 | train_balanced_accuracy: 0.79038 | train_logloss: 0.42348 | test_auc: 0.98927 | test_balanced_accuracy: 0.87881 | test_logloss: 0.28739 |  0:02:49s
# epoch 68 | loss: 0.39237 | train_auc: 0.882   | train_balanced_accuracy: 0.7356  | train_logloss: 0.45992 | test_auc: 0.98152 | test_balanced_accuracy: 0.8095  | test_logloss: 0.33754 |  0:02:52s
# epoch 69 | loss: 0.38866 | train_auc: 0.88115 | train_balanced_accuracy: 0.74632 | train_logloss: 0.45117 | test_auc: 0.98483 | test_balanced_accuracy: 0.82157 | test_logloss: 0.32049 |  0:02:54s
# epoch 70 | loss: 0.38702 | train_auc: 0.88466 | train_balanced_accuracy: 0.79169 | train_logloss: 0.41357 | test_auc: 0.98994 | test_balanced_accuracy: 0.87979 | test_logloss: 0.25879 |  0:02:56s
# epoch 71 | loss: 0.38703 | train_auc: 0.88271 | train_balanced_accuracy: 0.73349 | train_logloss: 0.46188 | test_auc: 0.98599 | test_balanced_accuracy: 0.8027  | test_logloss: 0.32788 |  0:02:59s
# epoch 72 | loss: 0.39379 | train_auc: 0.88141 | train_balanced_accuracy: 0.79167 | train_logloss: 0.41737 | test_auc: 0.98534 | test_balanced_accuracy: 0.87786 | test_logloss: 0.26653 |  0:03:01s
# epoch 73 | loss: 0.38594 | train_auc: 0.88491 | train_balanced_accuracy: 0.77995 | train_logloss: 0.42327 | test_auc: 0.98719 | test_balanced_accuracy: 0.85956 | test_logloss: 0.28122 |  0:03:04s
# epoch 74 | loss: 0.39646 | train_auc: 0.88089 | train_balanced_accuracy: 0.75577 | train_logloss: 0.44326 | test_auc: 0.98445 | test_balanced_accuracy: 0.82746 | test_logloss: 0.313   |  0:03:06s
# epoch 75 | loss: 0.39287 | train_auc: 0.88578 | train_balanced_accuracy: 0.77275 | train_logloss: 0.43236 | test_auc: 0.9883  | test_balanced_accuracy: 0.84629 | test_logloss: 0.28704 |  0:03:09s
# epoch 76 | loss: 0.40503 | train_auc: 0.88447 | train_balanced_accuracy: 0.75446 | train_logloss: 0.44789 | test_auc: 0.98515 | test_balanced_accuracy: 0.82704 | test_logloss: 0.32623 |  0:03:11s
# epoch 77 | loss: 0.39422 | train_auc: 0.88101 | train_balanced_accuracy: 0.72188 | train_logloss: 0.47102 | test_auc: 0.98235 | test_balanced_accuracy: 0.79345 | test_logloss: 0.35008 |  0:03:13s
# epoch 78 | loss: 0.37696 | train_auc: 0.87785 | train_balanced_accuracy: 0.67827 | train_logloss: 0.51856 | test_auc: 0.97932 | test_balanced_accuracy: 0.73187 | test_logloss: 0.40505 |  0:03:16s
# epoch 79 | loss: 0.39378 | train_auc: 0.88238 | train_balanced_accuracy: 0.76964 | train_logloss: 0.43502 | test_auc: 0.98681 | test_balanced_accuracy: 0.84794 | test_logloss: 0.30496 |  0:03:19s
# epoch 80 | loss: 0.39228 | train_auc: 0.88658 | train_balanced_accuracy: 0.76502 | train_logloss: 0.43603 | test_auc: 0.98723 | test_balanced_accuracy: 0.83888 | test_logloss: 0.29452 |  0:03:21s
#
# Early stopping occurred at epoch 80 with best_epoch = 20 and best_test_logloss = 0.21365
# /usr/local/lib/python3.11/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)

# %%
import matplotlib.pyplot as plt

# Lấy lịch sử huấn luyện
history = clf.history

# Accuracy
plt.figure(figsize=(10, 5))
plt.plot(history['train_balanced_accuracy'], label='train accuracy')
plt.plot(history['test_balanced_accuracy'], label='test accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.title('Training and Test Accuracy')
plt.show()

# Loss
plt.figure(figsize=(10, 5))
plt.plot(history['loss'], label='train loss')
plt.plot(history['test_logloss'], label='test loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.title('Training and Test Loss')
plt.show()

# %%
from sklearn.metrics import classification_report
probas = clf.predict_proba(X_test_np)[:, 1]
threshold = 0.5
y_pred_thresh = (probas >= threshold).astype(int)

print(classification_report(y_test.values, y_pred_thresh))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      1579
#            1       0.88      0.94      0.91       929
#
#     accuracy                           0.93      2508
#    macro avg       0.92      0.93      0.93      2508
# weighted avg       0.93      0.93      0.93      2508

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred_thresh)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
# Tính các giá trị cho đường ROC
fpr_tabnet, tpr_tabnet, _ = roc_curve(y_test, probas)
roc_auc_tabnet = auc(fpr_tabnet, tpr_tabnet)

# Vẽ ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr_tabnet, tpr_tabnet, color='darkorange',
         lw=2, label=f'TabNet (AUC = {roc_auc_tabnet:.2f})')

# Đường tham chiếu random guess
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')

# Thiết lập biểu đồ
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - TabNet Classifier')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()
