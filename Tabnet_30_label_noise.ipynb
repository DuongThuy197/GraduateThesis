# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler

# %%
link = 'https://drive.google.com/file/d/1_O2_eHswYX5TL1B7I7Fs3zyDi75e5q1Q/view?usp=sharing'
path = "https://drive.google.com/uc?export=download&id="+ link.split("/")[-2]
df_train = pd.read_csv(path)
df_train.head()
# Out:
#                 timestamp_TW                                          uuid  \
# 0  2019-05-23 11:45:00+00:00  MlJ4huAZ055iZHo2BJRhGoCRSYYDeIBv7uGFhaqNYCo=
# 1  2019-06-10 21:15:00+00:00  2pM78+2wOAY8l2evtpJS8Q80s14QI3fjcRZb9QFBVn4=
# 2  2019-06-04 16:15:00+00:00  MJPbRkeq6tFmKeTew2v3sxqobPk6QIJZRgC/dsS1Isc=
# 3  2019-05-15 11:30:00+00:00  qo5D63J1RjT9YPTJsFbKo9GAamD5iF6XMdpGMPaE9g4=
# 4  2019-06-09 10:15:00+00:00  uiyyJRVzplrZoBci1aco8pUxwLFge0tPVNhpYJRoqmc=
#
#                                            ucid  \
# 0  w3a6Wk12CqIrUktZei2Z0W3Rf8xdgEdjIW9QX0MWIf8=
# 1  4MP++M0mzDth2XpfseRILPjwOXOAk+Z2oAquU+nEEYE=
# 2  K1JDDj+chCE/ZH5wzdraQHI2j52Nzy0JBJmeLOgq3vc=
# 3  Y+91ladMQTxor3mEVlnYFcmpwmJFyT1HMG+DNySbVZ4=
# 4  bL9LCeyWY9s37YHGGaajw9y6AvwkTvCxHwEL9prznXk=
#
#                                            upid  problem_number  \
# 0  Q5jLvHRQpMUYKZZ6GbotWYCMvkMPq1+yCtpCzTrZW1A=               2
# 1  G4w1QQMbjRT/VptQIZkGYZhO/nkDJiC5ELv+TYfyPHM=               7
# 2  9c2hrY//vjfzCDODz8sOIragypxFG49b/t9S91Krlkg=              14
# 3  ZoE4lwjhMFd9OaWebsWlnK9s1AHSSpuSx8gO7gcplTA=              47
# 4  v4fB2VzIvLxBidz/bupuh6clyMuvR2b8BgSz6PA5UI4=               1
#
#    exercise_problem_repeat_session  is_correct  total_sec_taken  \
# 0                                1        True               29
# 1                                1       False               69
# 2                                1       False               49
# 3                                2        True                9
# 4                                1       False               56
#
#    total_attempt_cnt  used_hint_cnt   points  badges_cnt  is_self_coach  \
# 0                  1              0    28444           7          False
# 1                 19              3   305999          99          False
# 2                  4              2    71162          28          False
# 3                  1              0    47540          13          False
# 4                  2              2  1100969         105          False
#
#    has_student_cnt  belongs_to_class_cnt difficulty learning_stage  cheating
# 0                0                     1       easy     elementary         0
# 1                0                     1       hard     elementary         0
# 2                0                     0       easy         junior         0
# 3                0                     0     normal         junior         1
# 4                0                     1       easy     elementary         0

# %%
print(df_train['cheating'].value_counts())
# Out:
# cheating
# 0    5631
# 1    4398
# Name: count, dtype: int64

# %%
link1 = 'https://drive.google.com/file/d/1muldXGM0lM0hXQHXDyTQNIqjBQPUbSmZ/view?usp=sharing'
path1 = "https://drive.google.com/uc?export=download&id="+ link1.split("/")[-2]
df_test = pd.read_csv(path1)
df_test.head()
# Out:
#                 timestamp_TW                                          uuid  \
# 0  2019-06-04 16:45:00+00:00  +Oo+ob0YK/yFBooA6Nf3OW36y7Gr/b6/ba4a6UME/0A=
# 1  2019-05-21 21:15:00+00:00  mswQBRjmFKewBZnx/zGLKNkgr6Qf5pxv2uge48uqKcU=
# 2  2019-05-31 16:00:00+00:00  QOnOU/aC/jpVXnQanzAbc+E647O5X+nzhGt5VTIcF+c=
# 3  2019-06-11 20:30:00+00:00  J1IpAXiX5/aDRXwY49vUC1iB8B2LBN8Z5Ly4BF+p8ws=
# 4  2019-06-05 22:45:00+00:00  gzAyQpaHDzkY9/IFCbW3JvIolRnpInuj0pJWnSbLwwg=
#
#                                            ucid  \
# 0  3yFVYhjNhMP7tnJJxuCoKfPObXOoeoA5CWP2jeb05pw=
# 1  jImuGvSym6odgRoYw7vgkq4HUbmJ1tDW9fq6bo/yN5s=
# 2  tBr8loWJrEOlzcZDaQL0Q2qMEMUVGJJiWePsXb+7O9U=
# 3  PqQyQvOjvvozBCtlR/0pL8uxhe0K63IPiKYCi1tDG1o=
# 4  yHgHyIJ05U7s8Ak1XnUHY08MP++zF14JXnyie5AL5s0=
#
#                                            upid  problem_number  \
# 0  ER8ng3Tve+gXz0rzE4j8vVQVxJQG9pViFuppcTPCiXs=              16
# 1  EhczsL8/+nNXjaQ9riKSnb9DqC+HCnsSl3iDYW99ixQ=               5
# 2  QGivcV7dEtlX9vq1WVsW9i5jjJ7IeUgUbV8xot9rfbU=               2
# 3  F80i4frwlUPyjWehI764RoG6nzkEcPmKb6+1HcEJXHE=               5
# 4  k7bHRN1JubCEXM7IVXwABfq01n/9pN30eOrL1A8z2yc=              16
#
#    exercise_problem_repeat_session  is_correct  total_sec_taken  \
# 0                                1       False                9
# 1                                1        True               13
# 2                                1        True               39
# 3                                1       False               11
# 4                                2       False               21
#
#    total_attempt_cnt  used_hint_cnt  points  badges_cnt  is_self_coach  \
# 0                  4              1   80647          29          False
# 1                  1              0  239838          35          False
# 2                  1              0  143843          15          False
# 3                  3              0   34960           1          False
# 4                  7              4  219276          70          False
#
#    has_student_cnt  belongs_to_class_cnt difficulty learning_stage  cheating
# 0                0                     1     normal         junior         0
# 1                0                     1       easy     elementary         1
# 2                0                     2     normal     elementary         0
# 3                0                     1       easy     elementary         0
# 4                0                     1       hard     elementary         0

# %%
# One-hot encoding for Difficulty and Learning_stage columns
difficulty_encoded = pd.get_dummies(df_train['difficulty'], prefix='difficulty')
df_train = pd.concat([df_train, difficulty_encoded], axis=1)
df_train = df_train.drop('difficulty', axis=1)
df_train['learning_stage'] = df_train['learning_stage'].replace({'elementary': 1, 'junior': 2, 'senior': 3})

difficulty_encoded1 = pd.get_dummies(df_test['difficulty'], prefix='difficulty')
df_test = pd.concat([df_test, difficulty_encoded1], axis=1)
df_test = df_test.drop('difficulty', axis=1)
df_test['learning_stage'] = df_test['learning_stage'].replace({'elementary': 1, 'junior': 2, 'senior': 3})
# Out:
# /tmp/ipython-input-6-99201639.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_train['learning_stage'] = df_train['learning_stage'].replace({'elementary': 1, 'junior': 2, 'senior': 3})
# /tmp/ipython-input-6-99201639.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_test['learning_stage'] = df_test['learning_stage'].replace({'elementary': 1, 'junior': 2, 'senior': 3})

# %%
df_train['timestamp_TW'] = pd.to_datetime(df_train['timestamp_TW'])
df_train['hour'] = df_train['timestamp_TW'].dt.hour
df_train['minute'] = df_train['timestamp_TW'].dt.minute
df_train['weekday'] = df_train['timestamp_TW'].dt.weekday
df_train['day'] = df_train['timestamp_TW'].dt.day
df_train['month'] = df_train['timestamp_TW'].dt.month

df_test['timestamp_TW'] = pd.to_datetime(df_test['timestamp_TW'])
df_test['hour'] = df_test['timestamp_TW'].dt.hour
df_test['minute'] = df_test['timestamp_TW'].dt.minute
df_test['weekday'] = df_test['timestamp_TW'].dt.weekday
df_test['day'] = df_test['timestamp_TW'].dt.day
df_test['month'] = df_test['timestamp_TW'].dt.month

# %%
df_train =df_train.drop(columns = 'timestamp_TW')
df_test =df_test.drop(columns = 'timestamp_TW')

# %%
df_train = df_train.drop(columns = ['uuid', 'ucid', 'upid'])
df_test = df_test.drop(columns = ['uuid', 'ucid', 'upid'])

# %%
df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10029 entries, 0 to 10028
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   problem_number                   10029 non-null  int64
#  1   exercise_problem_repeat_session  10029 non-null  int64
#  2   is_correct                       10029 non-null  bool
#  3   total_sec_taken                  10029 non-null  int64
#  4   total_attempt_cnt                10029 non-null  int64
#  5   used_hint_cnt                    10029 non-null  int64
#  6   points                           10029 non-null  int64
#  7   badges_cnt                       10029 non-null  int64
#  8   is_self_coach                    10029 non-null  bool
#  9   has_student_cnt                  10029 non-null  int64
#  10  belongs_to_class_cnt             10029 non-null  int64
#  11  learning_stage                   10029 non-null  int64
#  12  cheating                         10029 non-null  int64
#  13  difficulty_easy                  10029 non-null  bool
#  14  difficulty_hard                  10029 non-null  bool
#  15  difficulty_normal                10029 non-null  bool
#  16  hour                             10029 non-null  int32
#  17  minute                           10029 non-null  int32
#  18  weekday                          10029 non-null  int32
#  19  day                              10029 non-null  int32
#  20  month                            10029 non-null  int32
# dtypes: bool(5), int32(5), int64(11)
# memory usage: 1.1 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2508 entries, 0 to 2507
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   problem_number                   2508 non-null   int64
#  1   exercise_problem_repeat_session  2508 non-null   int64
#  2   is_correct                       2508 non-null   bool
#  3   total_sec_taken                  2508 non-null   int64
#  4   total_attempt_cnt                2508 non-null   int64
#  5   used_hint_cnt                    2508 non-null   int64
#  6   points                           2508 non-null   int64
#  7   badges_cnt                       2508 non-null   int64
#  8   is_self_coach                    2508 non-null   bool
#  9   has_student_cnt                  2508 non-null   int64
#  10  belongs_to_class_cnt             2508 non-null   int64
#  11  learning_stage                   2508 non-null   int64
#  12  cheating                         2508 non-null   int64
#  13  difficulty_easy                  2508 non-null   bool
#  14  difficulty_hard                  2508 non-null   bool
#  15  difficulty_normal                2508 non-null   bool
#  16  hour                             2508 non-null   int32
#  17  minute                           2508 non-null   int32
#  18  weekday                          2508 non-null   int32
#  19  day                              2508 non-null   int32
#  20  month                            2508 non-null   int32
# dtypes: bool(5), int32(5), int64(11)
# memory usage: 276.9 KB

# %%
X_train = df_train.drop(columns = "cheating")
y_train = df_train["cheating"]
print(X_train.shape)

X_test = df_test.drop(columns="cheating")
y_test = df_test["cheating"]
print(X_test.shape)
# Out:
# (10029, 20)
# (2508, 20)

# %%
# !pip install pytorch_tabnet
# Out:
# Collecting pytorch_tabnet
#   Downloading pytorch_tabnet-4.1.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (2.0.2)
# Requirement already satisfied: scikit_learn>0.21 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (1.6.1)
# Requirement already satisfied: scipy>1.4 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (1.15.3)
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (2.6.0+cu124)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.11/dist-packages (from pytorch_tabnet) (4.67.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit_learn>0.21->pytorch_tabnet) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit_learn>0.21->pytorch_tabnet) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.3->pytorch_tabnet)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->pytorch_tabnet) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.3->pytorch_tabnet) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3->pytorch_tabnet) (3.0.2)
# Downloading pytorch_tabnet-4.1.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 2.6 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 80.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 64.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 92.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, pytorch_tabnet
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pytorch_tabnet-4.1.0

# %%
from pytorch_tabnet.tab_model import TabNetClassifier
import torch

cat_idxs = []
cat_dims = []
cat_emb_dim = []

# Trọng số xử lý mất cân bằng
class_weights = {0: 1, 1: 1.3}


# Khởi tạo mô hình TabNetClassifier với đầy đủ tham số
clf = TabNetClassifier(
    n_d=16, n_a=16,  # Kích thước decision layer & attention
    n_steps=7, gamma=1.5,  # Số bước và độ tái sử dụng feature
    n_independent=2, n_shared=2,  # Kiểm soát số lớp chung & riêng
    cat_idxs=cat_idxs, cat_emb_dim=cat_emb_dim,  # Embedding categorical
    optimizer_fn=torch.optim.Adam,  # Sử dụng Adam Optimizer
    optimizer_params=dict(lr=0.02),  # Learning rate = 0.01
    scheduler_fn=torch.optim.lr_scheduler.StepLR,
    scheduler_params={"step_size":10, "gamma":0.9},
    mask_type="sparsemax",  # Sử dụng sparsemax cho feature selection
    lambda_sparse=1e-3,  # Điều chỉnh sparsity để chọn lọc feature
    momentum=0.02,  # BatchNorm momentum
    clip_value=2.0,  # Clipping gradient
    verbose=1,  # Hiển thị log
    device_name='auto'
)
# Convert boolean columns to integers (0 or 1)
for col in X_train.select_dtypes(include=['bool']).columns:
    X_train[col] = X_train[col].astype(int)
    X_test[col] = X_test[col].astype(int)

X_train_np = X_train.values  # Chuyển thành NumPy array
X_test_np = X_test.values
y_train_np = y_train.values
y_test_np = y_test.values

# Huấn luyện mô hình
clf.fit(
    X_train_np, y_train_np,
    eval_set=[(X_train_np, y_train_np), (X_test_np, y_test_np)],
    eval_name=['train', 'test'],
    eval_metric=['auc', 'balanced_accuracy', 'logloss'],
    max_epochs=100, patience=60,
    batch_size=512, virtual_batch_size=128,
    num_workers=0,
    weights=class_weights,  # Trọng số cho lớp mất cân bằng
    drop_last=False
)
# Out:
# /usr/local/lib/python3.11/dist-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 1.0622  | train_auc: 0.52486 | train_balanced_accuracy: 0.52102 | train_logloss: 1.39485 | test_auc: 0.579   | test_balanced_accuracy: 0.57005 | test_logloss: 1.22952 |  0:00:05s
# epoch 1  | loss: 0.76449 | train_auc: 0.53373 | train_balanced_accuracy: 0.52357 | train_logloss: 0.86346 | test_auc: 0.60269 | test_balanced_accuracy: 0.56574 | test_logloss: 0.73799 |  0:00:07s
# epoch 2  | loss: 0.74316 | train_auc: 0.49762 | train_balanced_accuracy: 0.5019  | train_logloss: 1.12028 | test_auc: 0.48601 | test_balanced_accuracy: 0.50063 | test_logloss: 1.02099 |  0:00:09s
# epoch 3  | loss: 0.7123  | train_auc: 0.54471 | train_balanced_accuracy: 0.51798 | train_logloss: 0.80436 | test_auc: 0.59603 | test_balanced_accuracy: 0.54873 | test_logloss: 0.83583 |  0:00:12s
# epoch 4  | loss: 0.68536 | train_auc: 0.56603 | train_balanced_accuracy: 0.5539  | train_logloss: 0.68633 | test_auc: 0.6669  | test_balanced_accuracy: 0.65155 | test_logloss: 0.66376 |  0:00:14s
# epoch 5  | loss: 0.6779  | train_auc: 0.57856 | train_balanced_accuracy: 0.55809 | train_logloss: 0.69679 | test_auc: 0.70504 | test_balanced_accuracy: 0.63678 | test_logloss: 0.67602 |  0:00:16s
# epoch 6  | loss: 0.67611 | train_auc: 0.59062 | train_balanced_accuracy: 0.56872 | train_logloss: 0.69422 | test_auc: 0.74215 | test_balanced_accuracy: 0.68357 | test_logloss: 0.67517 |  0:00:18s
# epoch 7  | loss: 0.67824 | train_auc: 0.60368 | train_balanced_accuracy: 0.5849  | train_logloss: 0.6802  | test_auc: 0.76258 | test_balanced_accuracy: 0.73202 | test_logloss: 0.64677 |  0:00:21s
# epoch 8  | loss: 0.67889 | train_auc: 0.59552 | train_balanced_accuracy: 0.58162 | train_logloss: 0.67809 | test_auc: 0.73901 | test_balanced_accuracy: 0.72098 | test_logloss: 0.64044 |  0:00:23s
# epoch 9  | loss: 0.67914 | train_auc: 0.60671 | train_balanced_accuracy: 0.58849 | train_logloss: 0.68128 | test_auc: 0.72671 | test_balanced_accuracy: 0.70425 | test_logloss: 0.66283 |  0:00:25s
# epoch 10 | loss: 0.67321 | train_auc: 0.59987 | train_balanced_accuracy: 0.57771 | train_logloss: 0.6893  | test_auc: 0.74306 | test_balanced_accuracy: 0.70355 | test_logloss: 0.65814 |  0:00:27s
# epoch 11 | loss: 0.67853 | train_auc: 0.5994  | train_balanced_accuracy: 0.57138 | train_logloss: 0.69862 | test_auc: 0.74849 | test_balanced_accuracy: 0.68727 | test_logloss: 0.67665 |  0:00:29s
# epoch 12 | loss: 0.67719 | train_auc: 0.60706 | train_balanced_accuracy: 0.58438 | train_logloss: 0.68253 | test_auc: 0.75329 | test_balanced_accuracy: 0.71308 | test_logloss: 0.64001 |  0:00:32s
# epoch 13 | loss: 0.67549 | train_auc: 0.61625 | train_balanced_accuracy: 0.59519 | train_logloss: 0.67134 | test_auc: 0.76039 | test_balanced_accuracy: 0.73981 | test_logloss: 0.60887 |  0:00:34s
# epoch 14 | loss: 0.67849 | train_auc: 0.60493 | train_balanced_accuracy: 0.58964 | train_logloss: 0.6797  | test_auc: 0.74946 | test_balanced_accuracy: 0.73151 | test_logloss: 0.64669 |  0:00:36s
# epoch 15 | loss: 0.67492 | train_auc: 0.60965 | train_balanced_accuracy: 0.58837 | train_logloss: 0.68988 | test_auc: 0.74967 | test_balanced_accuracy: 0.71609 | test_logloss: 0.66103 |  0:00:38s
# epoch 16 | loss: 0.67402 | train_auc: 0.60969 | train_balanced_accuracy: 0.59034 | train_logloss: 0.68042 | test_auc: 0.75084 | test_balanced_accuracy: 0.73015 | test_logloss: 0.6452  |  0:00:41s
# epoch 17 | loss: 0.67637 | train_auc: 0.61408 | train_balanced_accuracy: 0.59405 | train_logloss: 0.67607 | test_auc: 0.77123 | test_balanced_accuracy: 0.7431  | test_logloss: 0.63459 |  0:00:43s
# epoch 18 | loss: 0.67019 | train_auc: 0.60989 | train_balanced_accuracy: 0.5953  | train_logloss: 0.68255 | test_auc: 0.78133 | test_balanced_accuracy: 0.75133 | test_logloss: 0.63073 |  0:00:45s
# epoch 19 | loss: 0.67834 | train_auc: 0.61045 | train_balanced_accuracy: 0.59279 | train_logloss: 0.67568 | test_auc: 0.76591 | test_balanced_accuracy: 0.74519 | test_logloss: 0.63317 |  0:00:47s
# epoch 20 | loss: 0.67288 | train_auc: 0.62122 | train_balanced_accuracy: 0.59533 | train_logloss: 0.66651 | test_auc: 0.79122 | test_balanced_accuracy: 0.74677 | test_logloss: 0.59728 |  0:00:49s
# epoch 21 | loss: 0.67246 | train_auc: 0.61531 | train_balanced_accuracy: 0.5896  | train_logloss: 0.68677 | test_auc: 0.78076 | test_balanced_accuracy: 0.73316 | test_logloss: 0.64695 |  0:00:52s
# epoch 22 | loss: 0.6788  | train_auc: 0.61669 | train_balanced_accuracy: 0.59045 | train_logloss: 0.66655 | test_auc: 0.79471 | test_balanced_accuracy: 0.72804 | test_logloss: 0.58929 |  0:00:54s
# epoch 23 | loss: 0.67325 | train_auc: 0.61896 | train_balanced_accuracy: 0.5962  | train_logloss: 0.67364 | test_auc: 0.79172 | test_balanced_accuracy: 0.74937 | test_logloss: 0.62245 |  0:00:56s
# epoch 24 | loss: 0.67325 | train_auc: 0.61061 | train_balanced_accuracy: 0.59401 | train_logloss: 0.67039 | test_auc: 0.76345 | test_balanced_accuracy: 0.75022 | test_logloss: 0.61167 |  0:00:58s
# epoch 25 | loss: 0.67656 | train_auc: 0.61409 | train_balanced_accuracy: 0.59424 | train_logloss: 0.68003 | test_auc: 0.76938 | test_balanced_accuracy: 0.74389 | test_logloss: 0.63643 |  0:01:00s
# epoch 26 | loss: 0.67066 | train_auc: 0.62497 | train_balanced_accuracy: 0.59686 | train_logloss: 0.66649 | test_auc: 0.79975 | test_balanced_accuracy: 0.7545  | test_logloss: 0.5848  |  0:01:02s
# epoch 27 | loss: 0.67557 | train_auc: 0.61925 | train_balanced_accuracy: 0.59404 | train_logloss: 0.66505 | test_auc: 0.78518 | test_balanced_accuracy: 0.74364 | test_logloss: 0.57727 |  0:01:05s
# epoch 28 | loss: 0.67252 | train_auc: 0.6206  | train_balanced_accuracy: 0.59253 | train_logloss: 0.66915 | test_auc: 0.80091 | test_balanced_accuracy: 0.75241 | test_logloss: 0.59914 |  0:01:07s
# epoch 29 | loss: 0.67355 | train_auc: 0.62201 | train_balanced_accuracy: 0.59507 | train_logloss: 0.66805 | test_auc: 0.80337 | test_balanced_accuracy: 0.74469 | test_logloss: 0.60248 |  0:01:09s
# epoch 30 | loss: 0.66834 | train_auc: 0.62033 | train_balanced_accuracy: 0.59586 | train_logloss: 0.66983 | test_auc: 0.80324 | test_balanced_accuracy: 0.74889 | test_logloss: 0.59709 |  0:01:11s
# epoch 31 | loss: 0.67219 | train_auc: 0.62335 | train_balanced_accuracy: 0.59322 | train_logloss: 0.67374 | test_auc: 0.80796 | test_balanced_accuracy: 0.75051 | test_logloss: 0.61596 |  0:01:13s
# epoch 32 | loss: 0.67182 | train_auc: 0.62467 | train_balanced_accuracy: 0.59641 | train_logloss: 0.68184 | test_auc: 0.8097  | test_balanced_accuracy: 0.7431  | test_logloss: 0.63325 |  0:01:15s
# epoch 33 | loss: 0.67366 | train_auc: 0.62432 | train_balanced_accuracy: 0.59492 | train_logloss: 0.67697 | test_auc: 0.81825 | test_balanced_accuracy: 0.74231 | test_logloss: 0.63237 |  0:01:17s
# epoch 34 | loss: 0.67075 | train_auc: 0.62351 | train_balanced_accuracy: 0.59497 | train_logloss: 0.67479 | test_auc: 0.80237 | test_balanced_accuracy: 0.74348 | test_logloss: 0.62247 |  0:01:19s
# epoch 35 | loss: 0.66715 | train_auc: 0.62725 | train_balanced_accuracy: 0.59767 | train_logloss: 0.67256 | test_auc: 0.81826 | test_balanced_accuracy: 0.75    | test_logloss: 0.60839 |  0:01:21s
# epoch 36 | loss: 0.66979 | train_auc: 0.62473 | train_balanced_accuracy: 0.59886 | train_logloss: 0.67138 | test_auc: 0.81637 | test_balanced_accuracy: 0.75383 | test_logloss: 0.59862 |  0:01:23s
# epoch 37 | loss: 0.6687  | train_auc: 0.62551 | train_balanced_accuracy: 0.60117 | train_logloss: 0.67069 | test_auc: 0.80584 | test_balanced_accuracy: 0.75219 | test_logloss: 0.6087  |  0:01:26s
# epoch 38 | loss: 0.67164 | train_auc: 0.6261  | train_balanced_accuracy: 0.59766 | train_logloss: 0.67221 | test_auc: 0.81223 | test_balanced_accuracy: 0.7495  | test_logloss: 0.61246 |  0:01:28s
# epoch 39 | loss: 0.66656 | train_auc: 0.62589 | train_balanced_accuracy: 0.59664 | train_logloss: 0.67575 | test_auc: 0.80708 | test_balanced_accuracy: 0.74959 | test_logloss: 0.61419 |  0:01:30s
# epoch 40 | loss: 0.67103 | train_auc: 0.62386 | train_balanced_accuracy: 0.59667 | train_logloss: 0.67895 | test_auc: 0.801   | test_balanced_accuracy: 0.74728 | test_logloss: 0.62617 |  0:01:32s
# epoch 41 | loss: 0.67459 | train_auc: 0.62641 | train_balanced_accuracy: 0.59917 | train_logloss: 0.67555 | test_auc: 0.82098 | test_balanced_accuracy: 0.75153 | test_logloss: 0.62292 |  0:01:34s
# epoch 42 | loss: 0.66689 | train_auc: 0.61772 | train_balanced_accuracy: 0.5961  | train_logloss: 0.67898 | test_auc: 0.78256 | test_balanced_accuracy: 0.7437  | test_logloss: 0.62476 |  0:01:36s
# epoch 43 | loss: 0.66852 | train_auc: 0.62408 | train_balanced_accuracy: 0.59413 | train_logloss: 0.67382 | test_auc: 0.80302 | test_balanced_accuracy: 0.74228 | test_logloss: 0.61542 |  0:01:39s
# epoch 44 | loss: 0.66587 | train_auc: 0.63295 | train_balanced_accuracy: 0.59742 | train_logloss: 0.67174 | test_auc: 0.82425 | test_balanced_accuracy: 0.75026 | test_logloss: 0.60182 |  0:01:41s
# epoch 45 | loss: 0.66358 | train_auc: 0.63038 | train_balanced_accuracy: 0.60049 | train_logloss: 0.67081 | test_auc: 0.81488 | test_balanced_accuracy: 0.76112 | test_logloss: 0.5918  |  0:01:43s
# epoch 46 | loss: 0.66955 | train_auc: 0.63017 | train_balanced_accuracy: 0.60164 | train_logloss: 0.6773  | test_auc: 0.81606 | test_balanced_accuracy: 0.75456 | test_logloss: 0.62974 |  0:01:45s
# epoch 47 | loss: 0.66924 | train_auc: 0.62715 | train_balanced_accuracy: 0.6002  | train_logloss: 0.67434 | test_auc: 0.80604 | test_balanced_accuracy: 0.76507 | test_logloss: 0.60242 |  0:01:47s
# epoch 48 | loss: 0.6659  | train_auc: 0.62833 | train_balanced_accuracy: 0.60308 | train_logloss: 0.66806 | test_auc: 0.82344 | test_balanced_accuracy: 0.77629 | test_logloss: 0.59135 |  0:01:50s
# epoch 49 | loss: 0.669   | train_auc: 0.63423 | train_balanced_accuracy: 0.60265 | train_logloss: 0.66839 | test_auc: 0.82681 | test_balanced_accuracy: 0.77185 | test_logloss: 0.59604 |  0:01:53s
# epoch 50 | loss: 0.66912 | train_auc: 0.62345 | train_balanced_accuracy: 0.59986 | train_logloss: 0.67197 | test_auc: 0.80413 | test_balanced_accuracy: 0.76394 | test_logloss: 0.61233 |  0:01:55s
# epoch 51 | loss: 0.67212 | train_auc: 0.62822 | train_balanced_accuracy: 0.59953 | train_logloss: 0.66986 | test_auc: 0.80534 | test_balanced_accuracy: 0.76042 | test_logloss: 0.60342 |  0:01:57s
# epoch 52 | loss: 0.66908 | train_auc: 0.61967 | train_balanced_accuracy: 0.59804 | train_logloss: 0.67711 | test_auc: 0.79263 | test_balanced_accuracy: 0.76314 | test_logloss: 0.61523 |  0:01:59s
# epoch 53 | loss: 0.67206 | train_auc: 0.62618 | train_balanced_accuracy: 0.5991  | train_logloss: 0.67784 | test_auc: 0.81732 | test_balanced_accuracy: 0.76273 | test_logloss: 0.62209 |  0:02:01s
# epoch 54 | loss: 0.67188 | train_auc: 0.63163 | train_balanced_accuracy: 0.60089 | train_logloss: 0.67317 | test_auc: 0.81612 | test_balanced_accuracy: 0.77809 | test_logloss: 0.6167  |  0:02:04s
# epoch 55 | loss: 0.66732 | train_auc: 0.62732 | train_balanced_accuracy: 0.59908 | train_logloss: 0.67354 | test_auc: 0.82218 | test_balanced_accuracy: 0.77119 | test_logloss: 0.59291 |  0:02:06s
# epoch 56 | loss: 0.66665 | train_auc: 0.63487 | train_balanced_accuracy: 0.60232 | train_logloss: 0.67082 | test_auc: 0.8344  | test_balanced_accuracy: 0.76846 | test_logloss: 0.60574 |  0:02:08s
# epoch 57 | loss: 0.67372 | train_auc: 0.63519 | train_balanced_accuracy: 0.60207 | train_logloss: 0.66741 | test_auc: 0.82992 | test_balanced_accuracy: 0.76245 | test_logloss: 0.59926 |  0:02:10s
# epoch 58 | loss: 0.66846 | train_auc: 0.63106 | train_balanced_accuracy: 0.60227 | train_logloss: 0.66773 | test_auc: 0.8333  | test_balanced_accuracy: 0.76929 | test_logloss: 0.59598 |  0:02:12s
# epoch 59 | loss: 0.67022 | train_auc: 0.62621 | train_balanced_accuracy: 0.6014  | train_logloss: 0.67147 | test_auc: 0.82975 | test_balanced_accuracy: 0.7678  | test_logloss: 0.60326 |  0:02:14s
# epoch 60 | loss: 0.66561 | train_auc: 0.63516 | train_balanced_accuracy: 0.60085 | train_logloss: 0.66658 | test_auc: 0.83342 | test_balanced_accuracy: 0.76454 | test_logloss: 0.5785  |  0:02:17s
# epoch 61 | loss: 0.66961 | train_auc: 0.63295 | train_balanced_accuracy: 0.59702 | train_logloss: 0.66728 | test_auc: 0.8241  | test_balanced_accuracy: 0.76995 | test_logloss: 0.59096 |  0:02:19s
# epoch 62 | loss: 0.67151 | train_auc: 0.6304  | train_balanced_accuracy: 0.59666 | train_logloss: 0.67357 | test_auc: 0.8159  | test_balanced_accuracy: 0.76783 | test_logloss: 0.61569 |  0:02:21s
# epoch 63 | loss: 0.66588 | train_auc: 0.62957 | train_balanced_accuracy: 0.5987  | train_logloss: 0.66697 | test_auc: 0.82484 | test_balanced_accuracy: 0.7715  | test_logloss: 0.58907 |  0:02:23s
# epoch 64 | loss: 0.67033 | train_auc: 0.6287  | train_balanced_accuracy: 0.59896 | train_logloss: 0.67224 | test_auc: 0.82274 | test_balanced_accuracy: 0.76422 | test_logloss: 0.60915 |  0:02:25s
# epoch 65 | loss: 0.66751 | train_auc: 0.6326  | train_balanced_accuracy: 0.59924 | train_logloss: 0.67436 | test_auc: 0.82741 | test_balanced_accuracy: 0.76026 | test_logloss: 0.61111 |  0:02:27s
# epoch 66 | loss: 0.66875 | train_auc: 0.63184 | train_balanced_accuracy: 0.60476 | train_logloss: 0.66764 | test_auc: 0.82423 | test_balanced_accuracy: 0.77888 | test_logloss: 0.59231 |  0:02:30s
# epoch 67 | loss: 0.6673  | train_auc: 0.63074 | train_balanced_accuracy: 0.60386 | train_logloss: 0.66686 | test_auc: 0.83981 | test_balanced_accuracy: 0.77268 | test_logloss: 0.57897 |  0:02:32s
# epoch 68 | loss: 0.67273 | train_auc: 0.63508 | train_balanced_accuracy: 0.60202 | train_logloss: 0.66615 | test_auc: 0.84347 | test_balanced_accuracy: 0.78021 | test_logloss: 0.58699 |  0:02:34s
# epoch 69 | loss: 0.66997 | train_auc: 0.63242 | train_balanced_accuracy: 0.60063 | train_logloss: 0.66887 | test_auc: 0.82787 | test_balanced_accuracy: 0.76707 | test_logloss: 0.60147 |  0:02:36s
# epoch 70 | loss: 0.66616 | train_auc: 0.63567 | train_balanced_accuracy: 0.59761 | train_logloss: 0.66739 | test_auc: 0.83439 | test_balanced_accuracy: 0.76701 | test_logloss: 0.58878 |  0:02:38s
# epoch 71 | loss: 0.6698  | train_auc: 0.63074 | train_balanced_accuracy: 0.60246 | train_logloss: 0.66553 | test_auc: 0.817   | test_balanced_accuracy: 0.76204 | test_logloss: 0.58876 |  0:02:41s
# epoch 72 | loss: 0.66592 | train_auc: 0.62422 | train_balanced_accuracy: 0.59801 | train_logloss: 0.66645 | test_auc: 0.79498 | test_balanced_accuracy: 0.74789 | test_logloss: 0.58551 |  0:02:43s
# epoch 73 | loss: 0.66763 | train_auc: 0.63381 | train_balanced_accuracy: 0.60287 | train_logloss: 0.66751 | test_auc: 0.82356 | test_balanced_accuracy: 0.76505 | test_logloss: 0.59898 |  0:02:45s
# epoch 74 | loss: 0.67041 | train_auc: 0.63047 | train_balanced_accuracy: 0.60004 | train_logloss: 0.66811 | test_auc: 0.8141  | test_balanced_accuracy: 0.7602  | test_logloss: 0.60029 |  0:02:47s
# epoch 75 | loss: 0.67262 | train_auc: 0.62875 | train_balanced_accuracy: 0.59611 | train_logloss: 0.66535 | test_auc: 0.81167 | test_balanced_accuracy: 0.76204 | test_logloss: 0.59337 |  0:02:49s
# epoch 76 | loss: 0.66849 | train_auc: 0.61859 | train_balanced_accuracy: 0.59559 | train_logloss: 0.67383 | test_auc: 0.78606 | test_balanced_accuracy: 0.74994 | test_logloss: 0.60833 |  0:02:51s
# epoch 77 | loss: 0.66921 | train_auc: 0.61759 | train_balanced_accuracy: 0.59671 | train_logloss: 0.66976 | test_auc: 0.77894 | test_balanced_accuracy: 0.75064 | test_logloss: 0.60781 |  0:02:54s
# epoch 78 | loss: 0.66363 | train_auc: 0.61747 | train_balanced_accuracy: 0.59442 | train_logloss: 0.66854 | test_auc: 0.7827  | test_balanced_accuracy: 0.737   | test_logloss: 0.58917 |  0:02:56s
# epoch 79 | loss: 0.66771 | train_auc: 0.61673 | train_balanced_accuracy: 0.59598 | train_logloss: 0.66812 | test_auc: 0.77763 | test_balanced_accuracy: 0.73427 | test_logloss: 0.59982 |  0:02:58s
# epoch 80 | loss: 0.66712 | train_auc: 0.61602 | train_balanced_accuracy: 0.59582 | train_logloss: 0.671   | test_auc: 0.77731 | test_balanced_accuracy: 0.74554 | test_logloss: 0.60286 |  0:03:00s
# epoch 81 | loss: 0.67033 | train_auc: 0.61745 | train_balanced_accuracy: 0.59699 | train_logloss: 0.66689 | test_auc: 0.77449 | test_balanced_accuracy: 0.7432  | test_logloss: 0.59887 |  0:03:02s
# epoch 82 | loss: 0.66677 | train_auc: 0.61635 | train_balanced_accuracy: 0.59495 | train_logloss: 0.67015 | test_auc: 0.7766  | test_balanced_accuracy: 0.73794 | test_logloss: 0.60279 |  0:03:04s
# epoch 83 | loss: 0.67065 | train_auc: 0.61505 | train_balanced_accuracy: 0.59628 | train_logloss: 0.66822 | test_auc: 0.77462 | test_balanced_accuracy: 0.74693 | test_logloss: 0.59735 |  0:03:07s
# epoch 84 | loss: 0.67197 | train_auc: 0.61669 | train_balanced_accuracy: 0.59533 | train_logloss: 0.67246 | test_auc: 0.78002 | test_balanced_accuracy: 0.75257 | test_logloss: 0.61201 |  0:03:09s
# epoch 85 | loss: 0.66942 | train_auc: 0.61613 | train_balanced_accuracy: 0.59415 | train_logloss: 0.66955 | test_auc: 0.78185 | test_balanced_accuracy: 0.75241 | test_logloss: 0.59413 |  0:03:11s
# epoch 86 | loss: 0.67037 | train_auc: 0.61916 | train_balanced_accuracy: 0.59798 | train_logloss: 0.66855 | test_auc: 0.78509 | test_balanced_accuracy: 0.75269 | test_logloss: 0.60511 |  0:03:13s
# epoch 87 | loss: 0.6656  | train_auc: 0.62127 | train_balanced_accuracy: 0.59701 | train_logloss: 0.6685  | test_auc: 0.78296 | test_balanced_accuracy: 0.75127 | test_logloss: 0.58976 |  0:03:15s
#
# Early stopping occurred at epoch 87 with best_epoch = 27 and best_test_logloss = 0.57727
# /usr/local/lib/python3.11/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)

# %%
import matplotlib.pyplot as plt

# Lấy lịch sử huấn luyện
history = clf.history

# Accuracy
plt.figure(figsize=(10, 5))
plt.plot(history['train_balanced_accuracy'], label='train accuracy')
plt.plot(history['test_balanced_accuracy'], label='test accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.title('Training and Test Accuracy')
plt.show()

# Loss
plt.figure(figsize=(10, 5))
plt.plot(history['loss'], label='train loss')
plt.plot(history['test_logloss'], label='test loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.title('Training and Test Loss')
plt.show()

# %%
from sklearn.metrics import classification_report
probas = clf.predict_proba(X_test_np)[:, 1]
threshold = 0.5
y_pred_thresh = (probas >= threshold).astype(int)

print(classification_report(y_test.values, y_pred_thresh))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.57      0.70      1579
#            1       0.56      0.92      0.69       929
#
#     accuracy                           0.70      2508
#    macro avg       0.74      0.74      0.70      2508
# weighted avg       0.79      0.70      0.70      2508

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred_thresh)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
# Tính các giá trị cho đường ROC
fpr_tabnet, tpr_tabnet, _ = roc_curve(y_test, probas)
roc_auc_tabnet = auc(fpr_tabnet, tpr_tabnet)

# Vẽ ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr_tabnet, tpr_tabnet, color='darkorange',
         lw=2, label=f'TabNet (AUC = {roc_auc_tabnet:.2f})')

# Đường tham chiếu random guess
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')

# Thiết lập biểu đồ
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - TabNet Classifier')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()
